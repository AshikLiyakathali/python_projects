# %%
# project: p10
# submitter: ashik
# partner: None
# hours: 6

# %%
import os
import csv
import json

from collections import namedtuple
from json import JSONDecodeError

# %%
# Q1: What are the names of the files present in the data directory?

def list_files_in(pathname):
    """
    Given a (relative) path called pathname, return a list of files at this path. 
    Make sure to exclude files that start with a "." from your list, 
    and that your list of files is sorted alphabetically before you return it.
    """
    
    files_list = os.listdir("./" + pathname)
    
    files_list.sort()
    
    files_list = [file for file in files_list if file[0] != "."]
    
    return files_list

list_files_in("data")
# Out:
# ['channel_ids1.json',
#  'channel_ids2.json',
#  'channel_ids3.json',
#  'channel_ids4.json',
#  'channel_ids5.json',
#  'comment_data1.csv',
#  'comment_data2.csv',
#  'comment_data3.csv',
#  'comment_data4.csv',
#  'comment_data5.csv',
#  'video_data.csv',
#  'video_ids.json']

# %%
# Q2: What are the paths of all the files in the data directory?

def list_paths_in(pathname):
    """
    Gets a list of files in pathname directory and generates relative paths to all the files,
    using os.path.join function.
    Returns a list of relative paths to each file inside pathname directory.
    """
    files = list_files_in(pathname)
    
    specific_file_path = [os.path.join(pathname, file) for file in files]

    return specific_file_path

data_paths_list = list_paths_in("data")

data_paths_list
# Out:
# ['data/channel_ids1.json',
#  'data/channel_ids2.json',
#  'data/channel_ids3.json',
#  'data/channel_ids4.json',
#  'data/channel_ids5.json',
#  'data/comment_data1.csv',
#  'data/comment_data2.csv',
#  'data/comment_data3.csv',
#  'data/comment_data4.csv',
#  'data/comment_data5.csv',
#  'data/video_data.csv',
#  'data/video_ids.json']

# %%
# Q3: What are the paths of all the files whose name contains comment_data in our data directory?

comment_paths = [path for path in data_paths_list if "comment_data" in path]

comment_paths
# Out:
# ['data/comment_data1.csv',
#  'data/comment_data2.csv',
#  'data/comment_data3.csv',
#  'data/comment_data4.csv',
#  'data/comment_data5.csv']

# %%
# Q4: What are the paths of all the files whose name contains channel_ids in our data directory?

channel_paths = [path for path in data_paths_list if "channel_ids" in path]

channel_paths
# Out:
# ['data/channel_ids1.json',
#  'data/channel_ids2.json',
#  'data/channel_ids3.json',
#  'data/channel_ids4.json',
#  'data/channel_ids5.json']

# %%
# Using the read_json function from lab10

def read_json(path):
    with open(path, encoding="utf-8") as f:
        return json.load(f)

# %%
# Using the get_mapping function from lab10

def get_mapping(pathname):
    """
    Given a path called pathname, load the json data at the path and return the loaded json data.
    If a json.JSONDecodeError is thrown, an empty dictionary is returned.
    """
    try:
        mapped_data = read_json(pathname) 
        
    except JSONDecodeError:
        mapped_data = {}

    return mapped_data

# %%
# Q5: What is the name of the channel with the ID UCNye-wNBqNL5ZzHSJj3l8Bg?

mapping = get_mapping(os.path.join("data", "channel_ids1.json"))

mapping['UCNye-wNBqNL5ZzHSJj3l8Bg']
# Out:
# 'Al Jazeera English'

# %%
# Q6: How many channels do we have in the entire dataset?

channel_dict = {}

for file in channel_paths:
    channel_dict.update(get_mapping(file))

num_of_channels = len(channel_dict)

num_of_channels
# Out:
# {'UCpi8TJfiA4lKGkaXs__YdBA': 'The Try Guys',
#  'UCERUmrDh9hmqEXBsnYFNTIA': 'DashieGames',
#  'UCIOrUVVyfoWnmcwG6IwCULQ': 'Loserfruit',
#  'UCR_J_SntqJh5eXw66d5hJxA': 'Matthew Beem',
#  'UCNye-wNBqNL5ZzHSJj3l8Bg': 'Al Jazeera English',
#  'UCHRTfR2r0Ss3UjFyw7gSA-A': 'Ryguyrocky',
#  'UCCbDhjYocBWYPTqoUONCPRA': 'Allie Schnacky',
#  'UCuN9hYw2RpoAW8rZ3VK3isA': 'NASCAR',
#  'UCugJq15BiB-c1NDYPHiznWQ': 'Total War',
#  'UCXVxMuWK6l_pCyxEk07EIRw': 'STARZ',
#  'UCRijo3ddMTht_IHyNSNXpNQ': 'Dude Perfect',
#  'UCEdTLCzuunuFLbAVfD1-Jpw': 'The Blondie Boys Shorts',
#  'UCq3QBWXCKvMnltjwqWuB5bQ': 'Cam&Fam',
#  'UCjbhchq-wEJBNJ-_faXsOmA': 'INTHESOOP_TV',
#  'UCjmJDM5pRKbUlVIzDYYWb6g': 'Warner Bros. Pictures',
#  'UC1T0JN1hhHfNsiKtqKn_dEQ': 'Sarah Schauer',
#  'UCA19mAJURyYHbJzhfpqhpCA': 'Action Lab Shorts',
#  'UCja8sZ2T4ylIqjggA1Zuukg': 'CBS Sports HQ',
#  'UC9PIn6-XuRKZ5HmYeu46AIw': 'Barely Sociable',
#  'UCXOE3YlluOUu_-5DdUUbAtw': 'WSOCTV9',
#  'UCUKi4zY5ETSqrKAjTBgjM-g': 'sWooZie',
#  'UCqZQlzSHbVJrwrn5XvzrzcA': 'NBC Sports',
#  'UCXcMEuLWTxA2D8IZcfouBiA': 'Davidjustinn',
#  'UCwx2yZG4irNLMDBuB-JGxMw': 'TapWater',
#  'UClOf1XXinvZsy4wKPAkro2A': 'PlayOverwatch',
#  'UCeBnbqt4VRhotq2TQjkIi2A': 'LaurenzSide',
#  'UCSo19KhHogXxu3sFsOpqrcQ': 'TUDN USA',
#  'UCkDtCKtPKlsg-gJO_m5D0mQ': 'Telepurte',
#  'UC-SV8-bUJfXjrRMnp7F8Wzw': 'Roman Atwood Vlogs',
#  'UCJcQeT8LADOXRROXCGM4dRg': 'TheCrazyGorilla',
#  'UCKaCalz5N5ienIbfPzEbYuA': 'Jordan Matter',
#  'UCF9imwPMSGz4Vq1NiTWCC7g': 'Paramount Pictures',
#  'UCY30JRSgfhYXA6i6xX1erWg': 'Smosh',
#  'UCE86oyLVAcsSkRAEWVtDUlA': '4 Shooters Only',
#  'UCe7cIhm4_RWsThRzBCXtmOQ': 'ABC11',
#  'UCOxoGn23BBHWghJelrqGkhg': 'Braydon Price',
#  'UCzMjRlKVO9XIqH_crIFpi6w': 'Skeppy',
#  'UCqseWqrl7r-hNoWme7hIfTw': 'Rebecca Rogers (Mrs. Rogers)',
#  'UCYCOimM5ykUJO4WrZD7kDeQ': 'Jaycoset',
#  'UCxl79GCsb6-xhrdQuPgnuJA': 'Acura',
#  'UCq0OueAsdxH6b8nyAspwViw': 'Universal Pictures',
#  'UCY8SLLJjWpS4sx1dEqECaIw': 'Tyler Oliveira',
#  'UC4ijq8Cg-8zQKx8OH12dUSw': 'Kara and Nate',
#  'UCnmGIkw-KdI0W5siakKPKog': 'Ryan Trahan',
#  'UCHxSZ6vUjipY6rf4bWnIJ1A': 'watchyourhaircut',
#  'UCE_--R1P5-kfBzHTca0dsnw': 'Complex',
#  'UCTz8K5TMmkQkRArybXfoVDg': 'Investment Joy',
#  'UCjpPTefVqOp_sPToSyUaEMg': 'Mr.Askick',
#  'UC1KsxDW7hhfeq5QQmFtInIw': 'julien solomita',
#  'UC0h07r_UgTD0Tc-Dn5XLX3g': 'Wisp',
#  'UC6QWhGQqf0YDYdRb0n6ojWw': 'Brooklyn and Bailey',
#  'UCDZH6sjXpWd1k9kJyXJZn9g': 'Cj Dachamp',
#  'UCPgMAS8woHJ_o_OZdTR7kcQ': 'Peacock',
#  'UCcW055_DGSkCEGWoKsW7gFQ': 'scribblejuice',
#  'UC-8zLYB2DB1fFCP3KJxe0Sg': 'MiniBloxia',
#  'UC2D-GCxeE69hCUmRwISXABw': 'Logdotzip',
#  'UChKqgm5CfsjC_bXiZlVnACA': 'Bigwunna',
#  'UCRw5sR-ZubiAr3Dxh_sJ64w': 'THE WADS',
#  'UCVJgocEWT3u49_4GtulGHnQ': 'Off Grid w/ Jake & Nicolle',
#  'UChFDOD4WPd2FgTCkSA4qzXg': "Vader's Fortress",
#  'UC7FldPQ7aT7Slikg7tZc30g': 'Mitten Squad',
#  'UCY4AlDv6wL2qhrX29iwdqAg': '2HYPE',
#  'UCUaT_39o1x6qWjz7K2pWcgw': 'Beast Reacts',
#  'UC3L9XPe0_FGfRG-CMGtBvFg': 'JxmyHighroller',
#  'UCSUf5_EPEfl4zlBKZHkZdmw': 'Danny Gonzalez',
#  'UC9tXyGZiEft9J4ZiI8dHb3Q': 'TapL',
#  'UCxDZs_ltFFvn0FDHT6kmoXA': 'bald and bankrupt',
#  'UCQ7Lqg5Czh5djGK6iOG53KQ': 'Wolves',
#  'UC6nSFpj9HTCZ5t-N3Rm3-HA': 'Vsauce',
#  'UCKQECjul8nw1KW_JzfBTP1A': 'KPRC 2 Click2Houston',
#  'UCLaduTRRWdzU8kq9AoqTRlw': 'RellGames',
#  'UCXMwCQVey4PhdWFJ6WhAVhA': 'SockStudios',
#  'UCtWIUAvZuWaNorJImG2Riqg': 'Damn Seconds',
#  'UCo00rI10S3Wpk4hVkL5IDTg': 'Alex Choi',
#  'UCJbYdyufHR-cxOuY96KIoqA': 'AMP',
#  'UC-O9o5coq8iFSVthivq__tw': 'Lexi Hensler',
#  'UCFKDEp9si4RmHFWJW1vYsMA': 'EthosLab',
#  'UCvNBXWGykQrWb7kPAn5eLUQ': 'Battlefield',
#  'UCEvC-HQ7ST5h8iC1IDgVtgw': 'Telanthric',
#  'UCBVEb6W9dMpIConICMS0B5Q': 'ImNotaCasualty',
#  'UChnGFN2LRHBq-0PM6dOaq5A': 'Bachelor Nation',
#  'UCIPPMRA040LQr5QPyJEbmXA': 'MrBeast Gaming',
#  'UCpIafFPGutTAKOBHMtGen7g': 'Gus Johnson',
#  'UCiS882YPwZt1NfaM0gR0D9Q': 'Genshin Impact',
#  'UCsEgeyBfOnGGBpjIvkDJbWg': 'Socksfor1',
#  'UCh8gHdtzO2tXd593_bjErWg': 'Doobydobap',
#  'UC_ovJB6xS99RQGIq7ik5T_A': 'Benny Soliven',
#  'UC35TiyFAjzQCyOrFt5ccbhw': 'JGGLS',
#  'UCpOXWy4Erc4UNoxI9xW-CXw': 'Steel Wool Studios',
#  'UCSJWlswfVUgyVliZaEFoaBw': 'TheSorryGirls',
#  'UCfPUcG3oCmXEYgdFuwlFh8w': 'Dingo Doodles',
#  'UCBgcPSn61UQ4l_-FvcEgLQA': 'NBC 6 South Florida',
#  'UC0Eqb484X8EiNrFLSUQVsaA': 'SoundSmith',
#  'UCqQo7ewe87aYAe7ub5UqXMw': 'House of Highlights',
#  'UCwCj-mTphfnjBcRag6MEM2A': 'ProjectJamesify',
#  'UCR9Gcq0CMm6YgTzsDxAxjOQ': 'Grian',
#  'UC0VNRvMijMy6DtM9UgX46Og': 'SocksReact',
#  'UCR1IuLEqb6UEA_zQ81kwXfg': 'Real Engineering',
#  'UCzU8-lZlRfkV3nj0RzAZdrQ': 'CONMEBOL',
#  'UC5enhS5tdXhHNbj8s_kdBUw': 'FusionZGamer',
#  'UCTkXRDQl0luXxVQrRQvWS6w': 'Dream',
#  'UC0Wju2yvRlfwqraLlz5152Q': 'PANDA BOI',
#  'UCXrExb1m3VjR0m1_l9luxRQ': 'PWR',
#  'UCXg4rJUbDP1IP3TmZ9KDpJg': 'Brianna',
#  'UC52XYgEExV9VG6Rt-6vnzVA': 'Destiny 2',
#  'UCWJ2lWNubArHWmf3FIHbfcQ': 'NBA',
#  'UCczKsS4gTjJzU5zayrNnwEA': 'Trevor Bauer',
#  'UCy0tKL1T7wFoYcxCe0xjN6Q': 'Technology Connections',
#  'UCCyrXyelKeXFx5KDgldMmNw': 'KINGDOM HEARTS',
#  'UCRK4FDIkUyslEAUdyRDdCtQ': 'NEWS9 live',
#  'UCm99c6g9MKBL4lNTlWrjyFQ': 'Checkpoint',
#  'UC06E4Y_-ybJgBUMtXx8uNNw': 'TheBackyardScientist',
#  'UC3R57cNcy6hmpb-H4huxg6A': 'Danny Kim',
#  'UCSReacwdlGHHyTIyuROhVdQ': 'AlishaMarie',
#  'UCzXwjTI6c6mVn6oui_p6oiw': 'SMii7Y',
#  'UCGwcH4qnJ2qM_ZJUSFcAMAA': 'JianHao Tan',
#  'UC_pT_Iz6XjuM-eMTlXghdfw': 'Max the Meat Guy',
#  'UCRC6cNamj9tYAO6h_RXd5xA': 'RTGame',
#  'UCRlEFn0L2G_DktbyvN0AZ5A': 'WadZee',
#  'UCFrVj6wBM42y3XuKCAj8n5A': 'SB737',
#  'UC_IpSl6O_-IRAA6fiNs05Gg': 'ABC',
#  'UCsXVk37bltHxD1rDPwtNM8Q': 'Kurzgesagt – In a Nutshell',
#  'UCYJPby9DRCteedh5tfxVbrw': 'Smosh Pit',
#  'UCRwczJ_nk1t9IGHyHfHbXRQ': 'Nathaniel Bandy',
#  'UCvWU1K29wCZ8j1NsXsRrKnA': 'LilyPichu',
#  'UCTQVIXvcHrR9jYoJ6qaBAow': 'M2',
#  'UCNdpD9V0PIrH1glUJ6RG4-w': 'FaZe Clan',
#  'UCRilWe8hfa-jQhwqnoJFH2A': 'Lauren Giraldo',
#  'UCAiOm_ctP55xZ5aQyE4I92A': 'B High Atl',
#  'UCkoZyNqTZyBZ8nu8E_OSkWw': 'Lauren & Arie',
#  'UCUuMYw2l2UeWyTGYixYfRCA': 'Evan and Katelyn',
#  'UC1HL3TABt6QGd_P857BH_CA': 'Evbo',
#  'UC0YatYmg5JRYzXJPxIdRd8g': 'beIN SPORTS USA',
#  'UCQJWtTnAHhEG5w4uN0udnUQ': 'Amazon Prime Video',
#  'UCS5Oz6CHmeoF7vSad0qqXfw': 'DanTDM',
#  'UCz97F7dMxBNOfGYu3rx8aCw': 'Sony Pictures Entertainment',
#  'UCD1Em4q90ZUK2R5HKesszJg': 'Clash of Clans',
#  'UCZBY6V8Lxmwu8gGRBOyO11w': 'Kubz Scouts',
#  'UCzW6xLMls_RmIgP2SQsqtCw': 'Life With mykel',
#  'UCiJUp_NBW2D_UMQIvq2nlPg': 'Zach King Shorts',
#  'UCBa659QWEk1AI4Tg--mrJ2A': 'Tom Scott',
#  'UC8uA7pvD52YlcqTsjpH_Wzg': 'ShadowApples',
#  'UC4UNqGYuB2q49GzGD_CBIVQ': 'TrixyBlox',
#  'UCVTQuK2CaWaTgSsoNkn5AiQ': 'HBO',
#  'UC0DZmkupLYwc0yDsfocLh0A': 'Jelly',
#  'UCC0BPKJxAyxjQoRTYbpW0FQ': 'Dallas Cowboys',
#  'UCIGl_6GmKR7fPRBBDDRcR0Q': 'Rainimator',
#  'UCNqBpQg7xHDVkR_bzXl8gsg': 'Darius Dinero',
#  'UCuoAh9yGYHEgDU192P2WD9w': 'snerixx',
#  'UCke6I9N4KfC968-yRcd5YRg': 'SSundee',
#  'UCKv8Rrrdc9oxLJmdHItafLA': 'ManlyBadassHero',
#  'UCpXBGqwsBkpvcYjsJBQ7LEQ': 'Critical Role',
#  'UCeY0bbntWzzVIaj2z3QigXg': 'NBC News',
#  'UCtWJFkS6AQ4dQ_nUTBPWi4A': 'GeorgeWasFound',
#  'UC14fB9eWBu579yRWLUhbFdQ': 'SystemZee',
#  'UCJ5v_MCY6GNUBTO8-D3XoAg': 'WWE',
#  'UCodbH5mUeF-m_BsNueRDjcw': 'Overly Sarcastic Productions',
#  'UC3XTzVzaHQEd30rQbuvCtTQ': 'LastWeekTonight',
#  'UCuTQDPUE12sy7g1xf1LAdTA': 'Noel Miller',
#  'UCSwfc2p-jal4rKWaMzaNrlw': "De'arra Taylor",
#  'UC4rqhyiTs7XyuODcECvuiiQ': 'Scott The Woz',
#  'UCvBHFNnPXt_re1WSdsennJg': 'Hungrybox',
#  'UCf5CjDJvsFvtVIhkfmKAwAA': 'MGM',
#  'UCEjBDKfrqQI4TgzT9YLNT8g': 'Ghost Town Living',
#  'UCJdxdc4MqvZRD9oFYoCl7wQ': 'Tom Simons',
#  'UCHYoe8kQ-7Gn9ASOlmI0k6Q': 'The Food Theorists',
#  'UCsN32BtMd0IoByjJRNF12cw': '60 Minutes',
#  'UCwGEZhoIwu7GN44Xkr_fXwA': 'styropyro shorts',
#  'UCtylTUUVIGY_i5afsQYeBZA': 'Lyrical Lemonade',
#  'UC-ZhwyrLDrq5PrgSgT_rc1g': 'Arnie Negrete',
#  'UCLGe0PxyRFWmXVGJKq_gGvw': 'fancy vlogs by gab',
#  'UChfTcl5XfdTUCjkfuro982Q': "That's Amazing Shorts",
#  'UCltTNcsPoyN8xvtTiFTT54g': 'ms_pam_a_cake official',
#  'UCv3umfEWPkjHMzbGZGfn_sw': 'Billions on SHOWTIME',
#  'UCefl-5pmhZmljwZTE2KrcdA': 'VINwiki',
#  'UCpB959t8iPrxQWj7G6n0ctQ': 'SSSniperWolf',
#  'UCVjlpEjEY9GpksqbEesJnNA': 'mrnigelng',
#  'UChh-akEbUM8_6ghGVnJd6cQ': 'BWF TV',
#  'UC6VAIqNQBc7ggiqvsOHOBqw': 'NichLmao',
#  'UC72ZaBKI-Bo5fjmWEYonhJw': 'TyC Sports',
#  'UCWS5x0aLgtpf26nxQW5BiLw': 'Free Refills',
#  'UCDVYQ4Zhbm3S2dlz7P1GBDg': 'NFL',
#  'UCfw6CRDOg5xQsB-2QNC_KUA': 'Sketch',
#  'UCtrTXHWdY1FmgmvfLI7cyRg': 'TheLlamaSir',
#  'UCVAYy7_zddIx6USjXscV9Vg': 'Caylus',
#  'UCsEukrAd64fqA7FjwkmZ_Dw': 'GQ',
#  'UCAC51Lw_eHFBfZwhk2Q4C3A': 'BradMartin_',
#  'UCw1SQ6QRRtfAhrN_cjkrOgA': 'LazarBeam',
#  'UC6c1z7bA__85CIWZ_jpCK-Q': 'ESPN FC',
#  'UC3Np7DUewV3LhtmR8BVDrCQ': 'Dani Razooqi',
#  'UCmo9ZEJ3ipgaZdkiRRYtLAg': 'Dude Perfect Plus',
#  'UC_guCQk0_fmS2BNk6fHzRjw': 'Shenpai',
#  'UChU3JRloULzdFX3aCu7BiSA': 'DreamXD',
#  'UCO7XVLiv_5iVIaxAsnEIiLA': 'Block Facts',
#  'UCpiCK8c6PBktcxq7Az_t4RQ': 'The Swoon',
#  'UCTSRIY3GLFYIpkR2QwyeklA': 'Drew Gooden',
#  'UC94lW_-Hr_uA7RcJ3D-WPOg': 'Danny Duncan',
#  'UC6107grRI4m0o2-emgoDnAA': 'SmarterEveryDay',
#  'UCPD_bxCRGpmmeQcbe2kpPaA': 'First We Feast',
#  'UC3EFKdXAU99j3ppGgvTz7XQ': 'Bretman Rock',
#  'UCKOvOaJv4GK-oDqx-sj7VVg': 'Chubbyemu',
#  'UCqTYHSnBUXZamsVcOlQf-fg': 'The Cosmonaut Variety Hour',
#  'UC_F8DoJf9MZogEOU51TpTbQ': 'Clash Royale',
#  'UCcVqCJ_9owb1zM43vqswMNQ': 'BETNetworks',
#  'UCV7lBBz6G20d87WoKFPjsPw': 'Moose',
#  'UCwIWAbIeu0xI0ReKWOcw3eg': 'Unspeakable',
#  'UCYkwcqwLUXZu3aJ7VO5VONg': 'The Deegans',
#  'UCx-KWLTKlB83hDI6UKECtJQ': 'HBO Max',
#  'UCLOIoa2aEGcM-z1hJx4vy4w': 'Dancing With The Stars',
#  'UCZ7AeeVbyslLM_8-nVy2B8Q': 'Skill Up',
#  'UC4514FwdRy5gI6CdC9GPb0w': 'Chris Bumstead',
#  'UCodkNmk9oWRTIYZdr_HuSlg': 'GoodTimesWithScar',
#  'UCbD8EppRX3ZwJSou-TVo90A': 'Mnet K-POP',
#  'UC5YJNT3kQrDCqetChCTKPHg': 'Iam Just Airi',
#  'UCDrLGkZTcNCshOLiKi5NtEw': 'WGN News',
#  'UCEg25rdRZXg32iwai6N6l0w': 'Tottenham Hotspur',
#  'UC58LMAlfwtGRNR6Xpd4DlSA': 'Ligue 1 Uber Eats Official',
#  'UCVIFCOJwv3emlVmBbPCZrvw': 'Joel Haver',
#  'UCbu2SsF-Or3Rsn3NxqODImw': 'GameSpot',
#  'UCzQUP1qoWDoEbmsQxvdjxgQ': 'PowerfulJRE',
#  'UCVhZyGllAVd-Wl6kNufV0uA': 'JackManifoldTV',
#  'UCnxxhf9PSA3VJ4Q80pWJoow': 'Jeopardy!',
#  'UCCqEeDAUf4Mg0GgEN658tkA': 'Chris Stuckmann',
#  'UCvsQyxpWFVX1LsVHchfaa8w': 'PipBoyFresh',
#  'UCiVJZlfcmWMUiXv5oywnDhQ': 'Wifies',
#  'UCr47E3UYaFoKU7Mroevt4aQ': 'EmeliaHartford',
#  'UCgR3SrM8T6GCFUTuxSFlR7A': 'Anime Balls Deep',
#  'UCSpFnDQr88xCZ80N-X7t0nQ': 'Corridor Crew',
#  'UCn_FAXem2-e3HQvmK-mOH4g': 'GLITCH',
#  'UC3sznuotAs2ohg_U__Jzj_Q': 'The Film Theorists',
#  'UCQeRaTukNYft1_6AZPACnog': 'Asmongold TV',
#  'UC5p_l5ZeB_wGjO_yDXwiqvw': 'TommyInnit',
#  'UC-hWvVvE-crFl5vg5G8QbqA': 'BT Sport Boxing',
#  'UCbAwSkqJ1W_Eg7wr3cp5BUA': 'Safiya Nygaard',
#  'UCIVSqoHCUN1XdEpiVItxfoQ': 'aCookieGod',
#  'UCEVVENPnHv-kcp2PqQuJvHg': 'SecondsOut',
#  'UCg4XK-l40KZD7fLi12pJ1YA': 'Welyn',
#  'UC8-Th83bH_thdKZDJCrn88g': 'The Tonight Show Starring Jimmy Fallon',
#  'UCCE5NVlm0FhbunMMBT48WAw': 'Fundy',
#  'UC-lCjm6VLCotg5ZOfJ7xF9w': 'Hello Hunnay with Jeannie Mai',
#  'UC1e6iW4ojbhn0gUCyvjawKg': 'Westie',
#  'UCKijjvu6bN1c-ZHVwR7-5WA': 'BuzzFeed Unsolved Network',
#  'UCvt0HYxX34vUvqu66HLXeUw': 'rekrap2',
#  'UC6D1L2vxEAg_Vi0JSxMBDgA': 'Dan Rhodes',
#  'UCg0FSqPeiGD_lIiPaaAehQg': 'Valve',
#  'UCHwpDpLoyJgtFXoAaaSut4Q': 'Lionfield',
#  'UCYIWAl9CEgVeIY8P8lHZdEQ': 'Jenna Davis',
#  'UC6pGDc4bFGD1_36IKv3FnYg': 'Crunchyroll Collection',
#  'UCnM02drQP-dF7WMgtJHR4Xw': 'Mr. Nightmare',
#  'UCh1QsxLVgYwn1PntCOHJxmw': 'TheVincentMottola',
#  'UC2mP7il3YV7TxM_3m6U0bwA': 'jschlattLIVE',
#  'UCxm10NbD7LF1fVYcbHbcbXg': 'PBC ON FOX',
#  'UC0k238zFx-Z8xFH0sxCrPJg': 'Architectural Digest',
#  'UCfiWa7d6um8dAb9hSz2UD-w': 'Bryton Myler',
#  'UC3v6sjWuPxtW36jQ-if4OuA': 'Imbrandonfarris',
#  'UCR0VLWitB2xM4q7tjkoJUPw': 'Vlog Creations',
#  'UCBJNt6QrHiLSOKhUMMzGQsg': 'Ralf Dummer',
#  'UC6MFZAOHXlKK1FI7V0XQVeA': 'ProZD',
#  'UCnPsWK-iGN9HCq1A9pwx8Vg': 'Bratoons',
#  'UC9YydG57epLqxA9cTzZXSeQ': 'Call of Duty',
#  'UC4G10tk3AHFuyMIuD3rHOBA': 'RDCworld1',
#  'UCMyOj6fhvKFMjxUCp3b_3gA': 'Nick DiGiovanni',
#  'UCJZam2u1G0syq3kyqrCXrNw': 'PrestonPlayz',
#  'UChRlaISXbl2gECFAmDzxgzg': 'Westen Champlin',
#  'UC4qGmRZ7aLOLfVsSdj5Se2A': 'TheThings',
#  'UCr1fdFXztwacnJ206hMgG7w': 'Cas van de Pol',
#  'UCV6g95OBbVtFmN9uiJzkFqQ': 'CircleToonsHD',
#  'UCsvn_Po0SmunchJYOWpOxMg': 'videogamedunkey',
#  'UCOn0gbCk9I-vinwgDUBvhcw': 'Kyle and Jade',
#  'UCPk2s5c4R_d-EUUNvFFODoA': 'Gohar Khan',
#  'UCzYfz8uibvnB7Yc1LjePi4g': 'Aphmau',
#  'UC0VVYtw21rg2cokUystu2Dw': 'SmallAnt',
#  'UCpCJ0y-_y03qPlG4zrYAAvQ': 'Ken Block',
#  'UC4waYXsuDuSEidJRX54zZHw': "Ar'mon And Trey",
#  'UCqFMzb-4AUf6WAIbl132QKA': 'NHL',
#  'UCjjJ-q15P2jGygGh8qXMSxw': 'Angry Thomas',
#  'UCt91DQH52N4Jzxwo0IURAHA': 'AuthenticTeeCee SHORTS',
#  'UCVAbWl3d3XuHY28wU9DoDpA': 'pierson',
#  'UCGIY_O-8vW4rfX98KlMkvRg': 'Nintendo',
#  'UCkUpZKOMik8bWhqUF_kYLiw': 'Ghoulz',
#  'UCeNTdh4BSHHVqAXB-2D5P4Q': 'Elsy Guevara',
#  'UC6xSN0oY2I9U_9xTo2RjE7g': 'Jeremy Hutchins',
#  'UCWzLmNWhgeh3h1j-M-Isy0g': 'TheRussianBadger',
#  'UCC-RHF_77zQdKcA75hr5oTQ': 'FGTeeV',
#  'UCR-QYzXrZF8yFarK8wZbHog': 'Colleen Ballinger',
#  'UCA2tt9GSU2sl8rAqjlLR3mQ': 'GeorgeNotFound',
#  'UCQZi2YXSxc6BSK4mZHql8ag': 'SportsNation',
#  'UCEr55381WIqO1w_IzgcI5DQ': 'Anwar Jibawi',
#  'UCAPw1N3BiVWTW6T-I2ReBWg': 'courtreezy',
#  'UCNSzfesc7IgWZwg4n6uXr1A': 'Tucker Budzyn',
#  'UCHu2KNu6TtJ0p4hpSW7Yv7Q': 'Jazza',
#  'UC7NCg0venpKJg3kuJojKlbQ': 'HALO',
#  'UCeI--jINF0G1jmDVjT2PX_Q': "D'Vontay Friga",
#  'UCFbZ2e9IrPejOdp8wsKUxvA': 'QuackiTwo',
#  'UCvK4bOhULCpmLabd2pDMtnA': 'Yes Theory',
#  'UCoc_XJPj6YLMQDWtPDQcDtA': 'Brad Mondo',
#  'UCojEXrCBzO-cP2N5YlRcrWw': 'Daniel Krafft',
#  'UC2-BeLxzUBSs0uSrmzWhJuQ': '20th Century Studios',
#  'UCtNdVINwfYFTQEEZgMiQ8FA': 'Bailey Sarian',
#  'UCZDdF_p-L88NWVpzF0vjvMQ': "Louie's Life",
#  'UCtab7TqLkMFc9MzOMvx5b-g': 'Frank Michael Smith',
#  'UCUOZvgB9Q8AgZjjLYcLWztQ': 'SEC Shorts',
#  'UCzH3H8sRfqH3rEVZcpTV2Cw': 'MrRoflWaffles',
#  'UCFmhLDjF1bB6-rbv9TBqeQg': 'SoaR Milo',
#  'UC-SJ6nODDmufqBzPBwCvYvQ': 'CBS Mornings',
#  'UCKGNVB2moP-zeAWPmw8HvAA': 'Craftee',
#  'UCwtnkRZcvL4bfopzJ-Von8Q': 'merrelltwins',
#  'UCQjKMGUEzBmEHltb1OIMLUg': 'Larryzaur',
#  'UCLBxN_kcGhhaEqCGZRpp8_g': 'Luna Smart Gadgets',
#  'UCiufyZv8iRPTafTw0D4CvnQ': 'Neebs Gaming',
#  'UCshoKvlZGZ20rVgazZp5vnQ': 'CaptainSparklez',
#  'UCWBWgCD4oAqT3hUeq40SCUw': 'Sambucha',
#  'UCSAYHSNaY5_UEol4_frPurg': 'MandJTV',
#  'UCiceQ96aHdwwve2vpCSbbNQ': 'Allen Tsai',
#  'UC0Wwu7r1ybaaR09ANhudTzA': 'Tampa Bay Buccaneers',
#  'UCb8vrqP8Z7Oz9ZTYvUtjUHQ': 'Daniel LaBelle',
#  'UCo_IB5145EVNcf8hw1Kku7w': 'The Game Theorists',
#  'UC1sELGmy5jp5fQUugmuYlXQ': 'Minecraft',
#  'UCCigEaEk-_gOrNlPdseG1pA': 'Alexa Real',
#  'UC0psAD-M4X6O0yC_hFRK4hw': 'AlondraDessy',
#  'UC2rWFYjCHFcnjNnWhnGvv7Q': 'Carmen and Corey',
#  'UCe8D5lo_zrqS8xtsNspeCgg': 'MONEY TALKS WIRELESS',
#  'UCinjnmQEwCddOudyCC1v7qA': 'KTLA 5',
#  'UCvC4D8onUfXzvjTOM-dBfEA': 'Marvel Entertainment',
#  'UCkvK_5omS-42Ovgah8KRKtg': 'jeffreestar',
#  'UC74U1KDtashP19m2U9eTshw': 'Our Tribe of Many',
#  'UCBNG0osIBAprVcZZ3ic84vw': 'Jim Browning',
#  'UCPH_47xeq7aOHPOTrzNKpHg': 'Rap Radio',
#  'UCJHA_jMfCvEnv-3kRjTCQXw': 'Babish Culinary Universe',
#  'UCLXzq85ijg2LwJWFrz4pkmw': 'Skip and Shannon: UNDISPUTED',
#  'UCVMc-W1-nhYb_1AR-Ll7zIw': 'Bancily',
#  'UCkg2ZDee9ZLBCd2LVB6DPHA': 'AR12Gaming',
#  'UCmGSJVG3mCRXVOP4yZrU1Dw': 'Johnny Harris',
#  'UCyps-v4WNjWDnYRKmZ4BUGw': 'Airrack',
#  'UCGwu0nbY2wSkW8N-cghnLpA': 'Jaiden Animations',
#  'UC4lGgdCua7DgZ82fhgxQJ8Q': '长沙一家人-  Funny family',
#  'UCywGsTdh_qqZUYmA2Gro2CA': 'Loic Suberville',
#  'UCrRttZIypNTA1Mrfwo745Sg': 'Paramount Plus',
#  'UC0ZV6M2THA81QT9hrVWJG3A': 'Apex Legends',
#  'UCVpankR4HtoAVtYnFDUieYA': 'zefrank1',
#  'UClyGlKOhDUooPJFy4v_mqPg': 'DougDoug',
#  'UCzfyYtgvkx5mLy8nlLlayYg': 'Vivziepop',
#  'UCV9_KinVpV-snHe3C3n1hvA': 'shane',
#  'UCjSKDpYQkGS005Vf13NAe8A': 'Bravo',
#  'UCB_qr75-ydFVKSF9Dmo6izg': 'FORMULA 1',
#  'UCkLf-v4v4Za9buNn3V5Bzeg': 'George Foreman',
#  'UCoLrcjPV5PbUrUyXq5mjc_A': 'MLB',
#  'UC2OTr2ZnuJg1TAZ5_xcb9Rw': 'NotNico',
#  'UCWwWOFsW68TqXE-HZLC3WIA': 'The ACE Family',
#  'UCiWLfSweyRNmLpgEHekhoAg': 'ESPN',
#  'UCYzPXprvl5Y-Sf0g4vX-m6g': 'jacksepticeye',
#  'UCUK0HBIBWgM2c4vsPhkYY4w': 'The Slow Mo Guys',
#  'UCUZlKYk41xcTr8clz6S8DPA': 'bwaap',
#  'UClOGLGPOqlAiLmOvXW5lKbw': 'MandaloreGaming',
#  'UCGLDtG2tl0uG8P0eNstbLUA': 'Tool_Tips',
#  'UCP1YcvxeNRHEcqyBk_7mjVg': 'Dark Corners',
#  'UCircJf-FlToBNjuy9xG-i5A': 'Watcher',
#  'UC9BgqXldGODtJszmPOmzVDw': 'Jamesify',
#  'UCjZ7QPKb89R-4SxzBoceyOg': 'Telemundo Deportes',
#  'UCqcolinf4cx46iiPui7Jgqw': 'Christine Jewellers',
#  'UCMOqf8ab-42UUQIdVoKwjlQ': 'Practical Engineering',
#  'UCZ3AmknSJtbzXCeO5a4peoQ': 'LazarLazar',
#  'UCHZ986wm_sJT6wntdDTIIcw': 'FitMC',
#  'UC9LQwHZoucFT94I2h6JOcjw': 'Liverpool FC',
#  'UCfuHLNojyt-1tgYe7HH9s7w': 'GameMill Entertainment',
#  'UC-p0spaVdbhBSLc2ajYQEoA': 'QTube',
#  'UC8TOSHpiM1hjNTNyHReLe5g': 'TheMagicMatt',
#  'UC9HQXWbt14wTdr_Tzc8ZE0A': 'Anthony Youn, MD',
#  'UCqFzWxSCi39LnW1JKFR3efg': 'Saturday Night Live',
#  'UCj6CFdE3LSddaoszxq604TQ': 'TimTom',
#  'UC3xZYc4SZUGfRERIvDRGqDQ': 'Skip the Tutorial',
#  'UCfLuMSIDmeWRYpuCQL0OJ6A': 'Kwebbelkop'}

# %%
# Creating a namedtuple to represent a Comment that has the following attributes...
# video_id, author_id, and published_at are strings and comment_length and likes are ints. 

Comment = namedtuple("Comment", ["video_id", "comment_length", "author_id", "likes", "published_at"])

# %%
# Using process_csv function for accessing data

def process_csv(filename):
    exampleFile = open(filename, encoding="utf-8")  
    exampleReader = csv.reader(exampleFile) 
    exampleData = list(exampleReader)        
    exampleFile.close()  
    return exampleData 

def get_comment_data(comment_file):
    csv_data = process_csv(comment_file)
    
    header = csv_data[0] 
    comment_rows = csv_data[1:]

    comment_id_idx = header.index("comment_id")
    video_id_idx = header.index("video_id")
    comment_length_idx = header.index("comment_length")
    author_id_idx = header.index("author_id")
    likes_idx = header.index("likes")
    published_at_idx = header.index("published_at")

    comment_dict = {}
    
    for comment in comment_rows:
        if "" in comment:
            continue
 
        try:     
            key = comment[comment_id_idx]

            value = Comment(comment[video_id_idx], int(comment[comment_length_idx]), \
                            comment[author_id_idx], int(comment[likes_idx]), comment[published_at_idx])

            comment_dict[key] = value
        
        except ValueError:
            continue

        except IndexError:
            continue
            
    return comment_dict

# %%
# Q7: What is the Comment object with comment ID UgygOezB4Mvd5o6FgAt4AaABAg?

comment1 = get_comment_data("data/comment_data1.csv")

comment1['UgygOezB4Mvd5o6FgAt4AaABAg']
# Out:
# Comment(video_id='udNXMAflbU8', comment_length=175, author_id='UCHkk7x38KWgqjQOHqsQwf0Q', likes=47, published_at='2021-10-10 17:48:38')

# %%
# Q8: What is the length of the comment with ID UgztIaGfqFoiGvbOdfp4AaABAg?

comments = {}

for file in comment_paths:
    comments.update(get_comment_data(file))
    
comments['UgztIaGfqFoiGvbOdfp4AaABAg'].comment_length
# Out:
# 67

# %%
# Q9: What percentage of comments are at most 140 characters long?

total_comments = len(comments)
comments_atmost_140 = 0

for comment in comments:
    length = comments[comment].comment_length

    if length <= 140:
        comments_atmost_140 += 1
        
percent = (comments_atmost_140 / total_comments) * 100

percent
# Out:
# 86.86953042956443

# %%
# Q10: What is the author ID of the comment that has the highest number of likes?

highest_likes = None
most_liked_author_id = None

for comment in comments:
    likes = comments[comment].likes

    if highest_likes == None or likes > highest_likes:
        highest_likes = likes
        most_liked_author_id = comments[comment].author_id

most_liked_author_id
# Out:
# 'UCIPPMRA040LQr5QPyJEbmXA'

# %%
# Q11: What is the most popular hour for publishing comments?

hours_list = [int(comments[comment].published_at[-8:-6]) for comment in comments]
unique_hours = set(hours_list)

most_comments_per_hour = None
most_popular_hour = None

for hour in unique_hours:
    num_of_comments = hours_list.count(hour)

    if most_comments_per_hour == None or num_of_comments > most_comments_per_hour:
        most_comments_per_hour = num_of_comments
        most_popular_hour = hour
    
most_popular_hour
# Out:
# 19

# %%
# Bucketizing the comments data by creating a dict mapping video IDs to 
# a list of comment IDs corresponding to that video ID

comment_buckets = {}

for comment in comments:
    video_id = comments[comment].video_id
    
    if video_id not in comment_buckets:
        comment_buckets[video_id] = []
    
    if video_id in comment_buckets:
        comment_buckets[video_id].append(comment)

# %%
# Q12: How many comments does the video with ID A8rrr_w8rfk have?

len(comment_buckets['A8rrr_w8rfk'])
# Out:
# 606

# %%
# Using the get_videos function from lab10

def get_videos(data_file, video_mapping_file):
    """
    Given data_file (csv file) and video_mapping_file (json) file, generates a video
    dictionary, mapping video ID to a dictionary containing title, and other details of the video.
    Handles missing entry in video_ids.json by using try / except blocks to handle KeyError.
    """
    data = process_csv(data_file)
    
    header = data[0]
    all_videos = data[1:]
    
    video_mapping = get_mapping(video_mapping_file)
    videos_dict = dict()
    
    for video in all_videos:
        try:
            key = video[header.index('video_id')]
            
            title = video_mapping[key]
            channel_name = channel_dict[video[header.index('channel_id')]]
            published_at = video[header.index('published_at')] 
            duration = video[header.index('duration')] 
            category = video[header.index('category')] 
            views = int(video[header.index('views')])
            tags = video[header.index('tags')].split("|")
            likes = video[header.index('likes')]
            dislikes = video[header.index('dislikes')]
            comments = comment_buckets[key]
            

            if likes != "" and dislikes != "": 
                ratings_enabled = True
                likes = int(likes)
                dislikes = int(dislikes)

            else:
                ratings_enabled = False
                likes = None
                dislikes = None
            
            value = {'title': title, 
                     'channel_name': channel_name,
                     'published_at': published_at, 
                     'duration': duration, 
                     'category': category, 
                     'views': views,
                     'tags': tags,
                     'likes': likes,
                     'dislikes': dislikes,
                     'ratings_enabled': ratings_enabled,
                     'comments': comments
                    }
            
            videos_dict[key] = value
        
        except KeyError:
            continue
    
    return videos_dict

videos = get_videos(os.path.join('data','video_data.csv'), os.path.join('data','video_ids.json'))

sample = ['UgzgwN2JXxjTN4mR5954AaABAg.9TPxukUd20g9TQLnJi3RFU', 'UgzvogxMg82Kj0aW84x4AaABAg']
for s in sample:
    assert s in videos['fkMW60W180E']['comments']

# %%
# Q13: What is the video with ID fkMW60W180E?

videos['fkMW60W180E']
# Out:
# {'title': 'SWAWS | Totally Accurate Battlegrounds',
#  'channel_name': 'TheRussianBadger',
#  'published_at': '2021-10-12 19:01:41',
#  'duration': '00:18:46',
#  'category': 'Gaming',
#  'views': 3172185,
#  'tags': ['tot',
#   'totally accurate battlegrounds',
#   'tabg',
#   'totally accurate battle simulator',
#   'totally accurate battlegrounds gameplay',
#   'totally accurate battle grounds',
#   'tabg gameplay',
#   'tabg game',
#   'tabs',
#   'totally accurate',
#   'totally accurate battle royale',
#   'battle royale',
#   'tabg funny',
#   'fortnite',
#   'battlegrounds',
#   'tabs battle royale',
#   'new battle royale',
#   'pubg',
#   'totally accurate battlegrounds funny',
#   'swaws',
#   'swaws meme',
#   'swaws russian badger',
#   'tabg update',
#   'tabg win',
#   'tabg br',
#   'free to play pc games',
#   'free to play'],
#  'likes': 210951,
#  'dislikes': 1824,
#  'ratings_enabled': True,
#  'comments': ['UgzgwN2JXxjTN4mR5954AaABAg.9TPxukUd20g9TQLnJi3RFU',
#   'Ugw8z3sbkSQQpgINHdl4AaABAg',
#   'UgyjZAl0XlNg-gOZ0jR4AaABAg.9TPyCmI6pbl9TQAXc7oVx_',
#   'Ugy1W1ldfeXB5VavpEB4AaABAg',
#   'Ugz-5ND1_48bvR--K-h4AaABAg.9TcESnaSWQO9TwybqLquLh',
#   'Ugw8yRjg6yeaJ-KJmvN4AaABAg',
#   'Ugxvp2D5qsf_Kz3qLfJ4AaABAg',
#   'UgyjZAl0XlNg-gOZ0jR4AaABAg.9TPyCmI6pbl9TS3pUjvdvY',
#   'Ugx7Z_ZM2zeYpgTo2V54AaABAg.9TPtkn_qSTN9TQ53TeDjlr',
#   'UgyJSgJPxm3-cOi3bSh4AaABAg',
#   'UgxpmEEjcu4ATnKp_dt4AaABAg.9TPdawdmb1E9TS4AKca9bH',
#   'Ugwq8srR6ykQ2_6mgRB4AaABAg',
#   'UgyjZAl0XlNg-gOZ0jR4AaABAg',
#   'Ugyvf9XkcWXRZx7icN14AaABAg',
#   'UgyjZAl0XlNg-gOZ0jR4AaABAg.9TPyCmI6pbl9TQFiNbKjs4',
#   'UgxHObmG9Ifype4Dtjh4AaABAg',
#   'Ugy2t0J2rMrLqVCcAxV4AaABAg',
#   'UgzZWUkzBIwfWd81Azd4AaABAg.9TSUVio8FDs9TX0cFy0cPn',
#   'Ugxp63hxPOpvnQXfmfN4AaABAg',
#   'Ugywck2nfxGf1P-jGrV4AaABAg.9TTUaC5BZm99TUWmUYdTW3',
#   'UgyF54uSxOw317OaxW94AaABAg',
#   'Ugz-hiG5y5Ifo2hXQRd4AaABAg.9TPd_-XUJf_9TS3y-fezid',
#   'UgwQZBclHDt-blfzYwh4AaABAg',
#   'UgzZWUkzBIwfWd81Azd4AaABAg.9TSUVio8FDs9TUQsdd2w1L',
#   'Ugz-hiG5y5Ifo2hXQRd4AaABAg.9TPd_-XUJf_9TQEttSsTwV',
#   'Ugz-hiG5y5Ifo2hXQRd4AaABAg.9TPd_-XUJf_9TabMdgwb7s',
#   'Ugz5310iuzanBWihavR4AaABAg',
#   'UgzvogxMg82Kj0aW84x4AaABAg',
#   'UgzZWUkzBIwfWd81Azd4AaABAg.9TSUVio8FDs9TUyS8-BWoG',
#   'UgwDeZIB2YoH3gT3LNt4AaABAg',
#   'UgzakPEp05WspBho1RJ4AaABAg.9TlhjvACtRu9TyzsrPsOxh',
#   'UgyZtlx_fwNidAjBVdR4AaABAg',
#   'UgwNv3MdCPrD0arufSZ4AaABAg',
#   'UgyXBz5CH6Q9rmwcRhp4AaABAg.9TQ2wkUS5H99TxG3z1lyQL',
#   'UgxUGNNhbZQnp9D_Yep4AaABAg',
#   'Ugxw406F2KiRt6h0Eg54AaABAg.9TQRqjzQH199TQiRp2YQOJ',
#   'Ugyi22jKbQYthMkJnaN4AaABAg',
#   'Ugz-5ND1_48bvR--K-h4AaABAg',
#   'Ugz5jelTNmzEROhDeUB4AaABAg',
#   'UgyIBw19on3SuDypRTx4AaABAg',
#   'UgxvNfLi21bGDhlsuGN4AaABAg.9TQRqu-Qzx79TWgpd0gXUF',
#   'UgzaSBdz7kdutGQnJJJ4AaABAg',
#   'UgyF54uSxOw317OaxW94AaABAg.9TQ42Lqa9o09Tc8fhL52xl']}

# %%
# Q14: What is the title of the video with ID gF69voHU_ys?

videos['gF69voHU_ys']['title']
# Out:
# 'A Mukbanger Ate 1 Gallon Pickles. This Is What Happened To Her Brain.'

# %%
# Q15: Among the videos with more than 1 million views, what is the title of the video with the highest likes to views ratio?

highest_likes_to_views_ratio = None
highest_likes_to_views_title = None

for video in videos:
    ratings = videos[video]['ratings_enabled']
    
    if ratings != True:
        continue
     
    views = videos[video]['views']
    likes = videos[video]['likes']
    title = videos[video]['title']
        
    if views > 1000000:
        likes_to_views_ratio = likes / views
        
        if highest_likes_to_views_ratio == None or likes_to_views_ratio > highest_likes_to_views_ratio:
            highest_likes_to_views_ratio = likes_to_views_ratio
            highest_likes_to_views_title = title
            
highest_likes_to_views_title
# Out:
# '[In the SOOP BTS ver. Season 2] Official Teaser 2'

# %%
# Q16: What is the author ID of the most liked comment under the video titled 'Giving Away My Beard For Charity!'?

given_title = 'Giving Away My Beard For Charity!'

most_likes_for_comment = None
author_id_of_most_liked_comment = None

for video in videos:
    title = videos[video]['title']
    
    if title == given_title:
        given_video_comments = videos[video]['comments']
        
        for comment in given_video_comments:
            likes = comments[comment].likes
            author_id = comments[comment].author_id

            if most_likes_for_comment  == None or likes > most_likes_for_comment:
                most_likes_for_comment  = likes 
                author_id_of_most_liked_comment = author_id
    
author_id_of_most_liked_comment
# Out:
# 'UCRvcDpyxCVmlLI8Q2TjRpmg'

# %%
# Implementing bucketize function similar to P9

def bucketize(attribute, videos=videos):
    """
    Input: A dict of videos and an attribute string.
    Return: A dictionary that bucketizes the `video_ids` by `attribute`.
    """
    bucketized_dict = {}

    list_atr = ["tags", "comments"]
    
    for video in videos:
        atr = videos[video][attribute]

        if attribute in list_atr:
            for item in atr:
                if item not in bucketized_dict:
                    bucketized_dict[item] = []  
                
                if item in bucketized_dict:
                    bucketized_dict[item].append(video)
        
        else:
            if atr not in bucketized_dict:
                bucketized_dict[atr] = []

            if atr in bucketized_dict:
                bucketized_dict[atr].append(video)

    return bucketized_dict

category_dict = bucketize('category')
assert category_dict['Pets & Animals'] == ['Hz_DslzN2IA', 'AwvyrO_yM4c']

# %%
# Q17: Which video titles were produced by the "Corridor Crew" channel?

given_channel = 'Corridor Crew'

channel_buckets = bucketize('channel_name')

given_channel_video_ids = channel_buckets[given_channel]

given_channel_video_titles = [videos[video]['title'] for video in given_channel_video_ids]

given_channel_video_titles
# Out:
# ['VFX Artists React to SHANG-CHi Bad & Great CGi',
#  'VFX Artists React to Bad & Great CGi 54 (ft. SETH ROGEN)']

# %%
# Q18: What are the top 5 channels that have the most total comments on their videos?

channel_total_comments = {}

for channel in channel_buckets:
    video_ids = channel_buckets[channel]
    total_comments = 0
    
    for video in video_ids:
        num_of_comments = len(videos[video]['comments'])
        total_comments += num_of_comments
        
    channel_total_comments[channel] = total_comments

sorted_total_comments = sorted(channel_total_comments.items(), key = lambda s:s[-1], reverse = True)
top_5_channel_names = [k for (k,v) in sorted_total_comments[:5]]

top_5_channel_names
# Out:
# ['NFL', 'Minecraft', 'Saturday Night Live', 'SSSniperWolf', 'PBC ON FOX']

# %%
# Q19: List all the unique video titles which have Minecraft tags.

given_tag = 'minecraft'

tag_buckets = bucketize('tags')

minecraft_tags = [tag for tag in tag_buckets if given_tag in tag.lower()]

minecraft_videos_list = []

for tag in minecraft_tags:
    video_ids = tag_buckets[tag]
    
    for video in video_ids:
        title = videos[video]['title']
        minecraft_videos_list.append(title)

minecraft_videos_list = list(set(minecraft_videos_list))

minecraft_videos_list
# Out:
# ['Philza And Wilbur TEACH Tommy To FLY And Its SCUFFED LORE! ORIGINS SMP',
#  'I Designed Custom Minecraft Bosses...',
#  'She Wants Us DEAD! 💀 Dark Deception Chapter 4 (FGTeeV Telekinesis Gameplay)',
#  'Last Life: Episode 4 - UH OH!',
#  'I made a custom mod in minecraft with your ideas',
#  'Jumping SQUID GAME CARS Across ENTIRE MAP In GTA 5! (Mods)',
#  'MURDER DRONES [OFFICIAL TRAILER]',
#  "Minecraft, But You Can't Leave The End...",
#  'Minecraft But I Upgrade EVERYTHING - The ULTIMATE Survival World! | Part 4',
#  'I tested them in Minecraft early and so should you...',
#  'Minecraft Manhunt but I have CUSTOM COMMANDS',
#  'So I made Dance Moves control Minecraft...',
#  'Minecraft Mobs if they were Superheroes',
#  'SURVIVING SQUID GAME in GTA 5',
#  'Minecraft Mobs when you log off...',
#  'What Mob Should Be Added To Minecraft?',
#  'I Survived 100 Days as a FOX in HARDCORE Minecraft!',
#  'Realistic Water in Minecraft...',
#  'Which Mob Am I Voting For in Minecraft Live 2021?!',
#  'Minecraft, But I Add A Marshmallow Every Minute...',
#  'can 1 pixel of water save you?',
#  'Minecraft but you can Eat Mobs',
#  'I Cheated with a "FAKE" Professional Builder in a Building Competition...',
#  'I Trapped 10 YouTubers on One Block',
#  'I Survived 1,900 Days in HARDCORE Minecraft...',
#  'Realistic Golem Transforming',
#  'I Built an AUTOMATIC Mob Loot Farm in Minecraft Hardcore! (#22)',
#  'I Survived 100 Days as a PANDA in HARDCORE Minecraft!',
#  'Minecraft, But You Can Upgrade TNT...',
#  'What is the Safest Base Possible in Minecraft?',
#  'Minecraft - Last Life #3: Frightening Exploit Tactics',
#  'Building AUTOMATIC FARMS in Minecraft Hardcore (#52)',
#  'Becoming SQUID GAME Host in GTA 5! (GTA 5 Mods)',
#  '"Eternal" - A Minecraft Music Video ♪',
#  'Minecraft but all Mobs are Dragons',
#  'Playing SQUID GAME In Minecraft!',
#  'Minecraft Death Shuffle...',
#  'LAST TO LEAVE THE MYSTERY MACHINE WINS $10,000',
#  "Minecraft, But There's Custom End City Items...",
#  'Playing SQUID GAME in Minecraft!',
#  'Minecraft Mobs if they were Parents',
#  'I Was In The Funniest Minecraft Competition With Dream',
#  '100 Days, But There Are Custom Dimensions...',
#  "Minecraft, But We're All Mutant Superhumans...",
#  'I Survived 100 Days as an ENDER DRAGON in Minecraft',
#  'We Fought a Viking Horde...',
#  "2b2t's Obsidian War is Getting Ridiculous",
#  'I Won SQUID GAME In GTA 5! (Mods)',
#  '46 Minecraft Blocks Mojang Had To Remove',
#  'Hermitcraft 8 Episode 14:  BETRAYING BOATEM',
#  'I Survived 69 Hours Using Only Minecraft Tools',
#  'You Laugh You Lose Is Even Funnier In Real Life...',
#  'Minecraft, But I Add A Marshmallow Every Minute... - Extra Scenes',
#  'I Found the RICHEST Server in Minecraft! *millionaire*']

# %%
# Q20: List the titles of the 5 shortest videos.

title_duration = {videos[video]['title']:videos[video]['duration'] for video in videos}
    
sorted_title_duration = sorted(title_duration.items(), key = lambda s:s[-1])

shortest_5_video_titles = [k for (k,v) in sorted_title_duration[:5]]
    
shortest_5_video_titles
# Out:
# ['When someone walks in while you using the bathroom😭',
#  'Smart Appliances, Gadgets For Every Home 🤩 Versatile Utensils, Kitchen, Makeup, Beauty #Shorts',
#  'Italians reacting to ketchup on pasta 😱🇮🇹 #shorts',
#  'My hidden talent #shorts',
#  'Knot']

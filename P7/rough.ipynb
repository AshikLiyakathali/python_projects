# %%
import csv
import datetime

# %%
def process_csv(filename):
    example_file = open(filename, encoding="utf-8")
    example_reader = csv.reader(example_file)
    example_data = list(example_reader)
    example_file.close()
    return example_data

# %%
csv_rows = process_csv("vaccinations.csv")

csv_header = csv_rows[0]

csv_data = csv_rows[1:]

csv_header
# Out:
# ['country',
#  'date',
#  'daily_vaccinations',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'population']

# %%
# Using the cell function to access the data in a specific cell

def cell(row_idx, col_name):
    """
    Returns the data value (cell) corresponding to the row index and 
    the column name of a CSV file.
    """
    col_idx = csv_header.index(col_name)
    val = csv_data[row_idx][col_idx]
    
    int_list = ['daily_vaccinations', 'total_vaccinations', 'people_vaccinated', \
                'people_fully_vaccinated', 'total_boosters', 'population']
    
    if val == "": # this is how we handle a missing value in the dataset
        return None
    
    elif col_name in int_list:
        return int(val)  # TODO: make sure the function returns val with the appropriate type
    
    return val

# %%
# Q1: What dates are mentioned in the dataset?

date_list = []

for row_idx in range(len(csv_data)):
    date = cell(row_idx, "date")
    
    if date not in date_list:
        date_list.append(date)
    
dates = date_list
dates
# Out:
# ['01/25/2022',
#  '01/26/2022',
#  '01/27/2022',
#  '01/28/2022',
#  '01/29/2022',
#  '01/30/2022',
#  '01/31/2022']

# %%
#print("Country: ", country, "\tDate: ", date, "\TDaily Vaccinations: ", daily_vacc)

# %%
# Q2: What countries are listed in the dataset?

country_list = []

for row_idx in range(len(csv_data)):
    country = cell(row_idx, "country")
    
    if country not in country_list:
        country_list.append(country)
        
countries = sorted(country_list)
countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faeroe Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lebanon',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Malta',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Macedonia',
#  'Northern Ireland',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'San Marino',
#  'Saudi Arabia',
#  'Scotland',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten (Dutch part)',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'South Africa',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'Timor',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Wales',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
# Q3: What is the population of each country in the dataset?

pop_dict = {}

for row_idx in range(len(csv_data)):
    country = cell(row_idx, "country")
    pop = cell(row_idx, "population")
    
    if country not in pop_dict:
        pop_dict[country] = None
        
    if pop_dict[country] == None and pop != None:
        pop_dict[country] = pop

population = pop_dict
population
# Out:
# {'Afghanistan': 39822425,
#  'Albania': 2873046,
#  'Angola': 33934485,
#  'Anguilla': 15126,
#  'Antigua and Barbuda': 98726,
#  'Argentina': 45605836,
#  'Armenia': 2968277,
#  'Aruba': 107194,
#  'Austria': 9043061,
#  'Azerbaijan': 10222990,
#  'Bahamas': 396909,
#  'Bahrain': 1748265,
#  'Bangladesh': 166312179,
#  'Barbados': 287709,
#  'Belarus': 9442839,
#  'Belgium': 11632221,
#  'Belize': 404916,
#  'Bermuda': 62094,
#  'Bhutan': 779889,
#  'Bolivia': 11832385,
#  'Bosnia and Herzegovina': 3263734,
#  'Brazil': 213992450,
#  'British Virgin Islands': 30423,
#  'Brunei': 441538,
#  'Bulgaria': 6896487,
#  'Cambodia': 16946049,
#  'Canada': 38067582,
#  'Cayman Islands': 66498,
#  'Central African Republic': 4921767,
#  'Chad': 16903319,
#  'Chile': 19212518,
#  'China': 1444229881,
#  'Colombia': 51267219,
#  'Comoros': 888427,
#  'Costa Rica': 5138966,
#  "Cote d'Ivoire": 27053133,
#  'Croatia': 4081748,
#  'Cuba': 11317506,
#  'Curacao': 164798,
#  'Cyprus': 895987,
#  'Czechia': 10724424,
#  'Democratic Republic of Congo': 91814314,
#  'Denmark': 5813280,
#  'Djibouti': 1002361,
#  'Dominica': 72170,
#  'Dominican Republic': 10954070,
#  'Ecuador': 17888751,
#  'Egypt': 104251488,
#  'El Salvador': 6518537,
#  'England': 56550418,
#  'Estonia': 1325207,
#  'Eswatini': 1172459,
#  'Ethiopia': 117884275,
#  'Faeroe Islands': 49054,
#  'Fiji': 902920,
#  'Finland': 5548481,
#  'France': 67421298,
#  'Georgia': 3979806,
#  'Germany': 83899241,
#  'Gibraltar': 33692,
#  'Greece': 10370640,
#  'Greenland': 56867,
#  'Grenada': 113019,
#  'Guatemala': 18248779,
#  'Guernsey': 63386,
#  'Guinea': 13496227,
#  'Guinea-Bissau': 2015231,
#  'Guyana': 790325,
#  'Haiti': 11559227,
#  'Hong Kong': 7553014,
#  'Hungary': 9633977,
#  'Iceland': 368788,
#  'India': 1393359590,
#  'Indonesia': None,
#  'Iran': 85028488,
#  'Iraq': 41176013,
#  'Ireland': 4982870,
#  'Isle of Man': 85409,
#  'Israel': 9290929,
#  'Italy': 60367963,
#  'Jamaica': 2973542,
#  'Japan': 126053281,
#  'Jersey': 101074,
#  'Jordan': 10268732,
#  'Kazakhstan': 18995524,
#  'Kenya': 54993600,
#  'Kosovo': 1782075,
#  'Kuwait': 4328543,
#  'Kyrgyzstan': 6628459,
#  'Latvia': 1866909,
#  'Lebanon': 6768969,
#  'Libya': 6957866,
#  'Liechtenstein': 38253,
#  'Lithuania': 2689938,
#  'Luxembourg': 634826,
#  'Macao': 658391,
#  'Malawi': 19644625,
#  'Malaysia': 32775743,
#  'Maldives': 543609,
#  'Malta': 516109,
#  'Mexico': 130265900,
#  'Moldova': 4024409,
#  'Mongolia': 3329230,
#  'Montenegro': 628062,
#  'Montserrat': 4982,
#  'Morocco': 37343984,
#  'Mozambique': 32161156,
#  'Myanmar': 54809224,
#  'Namibia': 2587633,
#  'Nepal': 29675048,
#  'Netherlands': 17172728,
#  'New Caledonia': 288212,
#  'New Zealand': 5126427,
#  'Nicaragua': 6702499,
#  'Niger': 25119763,
#  'Nigeria': 211462442,
#  'North Macedonia': 2082779,
#  'Northern Ireland': 1895961,
#  'Norway': 5465512,
#  'Oman': 5223195,
#  'Pakistan': 225207213,
#  'Panama': 4381484,
#  'Papua New Guinea': 9126336,
#  'Paraguay': 7219360,
#  'Peru': 33360256,
#  'Philippines': 111049250,
#  'Poland': 37797992,
#  'Portugal': 10167685,
#  'Qatar': 2930460,
#  'Romania': 19127049,
#  'Russia': 145911215,
#  'Rwanda': 13276530,
#  'Saint Kitts and Nevis': 53545,
#  'Saint Lucia': 184391,
#  'Saint Vincent and the Grenadines': 111277,
#  'San Marino': 34010,
#  'Saudi Arabia': 35339912,
#  'Scotland': 5465919,
#  'Serbia': 6871684,
#  'Sierra Leone': 8141612,
#  'Singapore': 5453605,
#  'Sint Maarten (Dutch part)': 43421,
#  'Slovakia': 5449373,
#  'Slovenia': 2078690,
#  'Solomon Islands': 704060,
#  'South Africa': 60045608,
#  'South Korea': 51306074,
#  'South Sudan': 11367210,
#  'Spain': 46744458,
#  'Sri Lanka': 21497041,
#  'Sudan': 44906993,
#  'Suriname': 591824,
#  'Sweden': 10160060,
#  'Switzerland': 8715357,
#  'Taiwan': 23854801,
#  'Tajikistan': 9749103,
#  'Thailand': 69951699,
#  'Timor': 1343842,
#  'Trinidad and Tobago': 1403399,
#  'Tunisia': 11936050,
#  'Turkey': 85044499,
#  'Uganda': 47122964,
#  'Ukraine': 43467272,
#  'United Arab Emirates': 9991286,
#  'United Kingdom': 68205463,
#  'United States': 332009030,
#  'Uruguay': 3485127,
#  'Uzbekistan': 33935149,
#  'Venezuela': 28704673,
#  'Vietnam': 98169610,
#  'Wales': 3169965,
#  'Yemen': 30494263,
#  'Zambia': 18923966,
#  'Zimbabwe': 15092969}

# %%
# Function 1: daily_vaccinations_on(search_date)

def daily_vaccinations_on(search_date):
    '''return a dictionary mapping each country to
    the number of daily vaccinations on the given date;
    if data is missing, the value for that country is None'''
    
    daily_vacc_dict = {}
    
    for row_idx in range(len(csv_data)):
        date = cell(row_idx, "date")
        country = cell(row_idx, "country")
        daily_vacc = cell(row_idx, "daily_vaccinations")
    
        if country not in daily_vacc_dict:
            daily_vacc_dict[country] = None

        if date == search_date and daily_vacc_dict[country] == None:
            if daily_vacc != None:
                daily_vacc_dict[country] = daily_vacc
    
    return daily_vacc_dict

# %%
daily_dict = daily_vaccinations_on("01/27/2022")
daily_dict['Bahrain']
# Out:
# 2827

# %%
# Q6: For each country, what is the sum of the vaccinations given on all of the dates mentioned in the dataset?

sum_vacc_dict = {}
sum_vacc = 0

for row_idx in range(len(csv_data)):
    date = cell(row_idx, "date")
    country = cell(row_idx, "country")
    daily_vacc = cell(row_idx, "daily_vaccinations")
    
    if country not in sum_vacc_dict:
        sum_vacc_dict[country] = None
        
    for i in range(len(date_list)):
        daily_dict = daily_vaccinations_on(date_list[i])
        if daily_dict[country] != None:
            sum_vacc += daily_dict[country]
    
    if sum_vacc_dict[country] == None:
        if sum_vacc != 0:
            sum_vacc_dict[country] = sum_vacc
        else:
            sum_vacc_dict[country] = None
            
    sum_vacc = 0
    
sum_vacc_dict
# Out:
# {'Afghanistan': 6868,
#  'Albania': None,
#  'Angola': None,
#  'Anguilla': None,
#  'Antigua and Barbuda': None,
#  'Argentina': 1424935,
#  'Armenia': None,
#  'Aruba': 109,
#  'Austria': None,
#  'Azerbaijan': 186924,
#  'Bahamas': None,
#  'Bahrain': 24377,
#  'Bangladesh': 2534125,
#  'Barbados': 655,
#  'Belarus': None,
#  'Belgium': 271202,
#  'Belize': None,
#  'Bermuda': None,
#  'Bhutan': None,
#  'Bolivia': 330401,
#  'Bosnia and Herzegovina': None,
#  'Brazil': 7625078,
#  'British Virgin Islands': None,
#  'Brunei': None,
#  'Bulgaria': 61239,
#  'Cambodia': 461795,
#  'Canada': 1754870,
#  'Cayman Islands': None,
#  'Central African Republic': None,
#  'Chad': None,
#  'Chile': 401911,
#  'China': 27073000,
#  'Colombia': 1082431,
#  'Comoros': None,
#  'Costa Rica': None,
#  "Cote d'Ivoire": None,
#  'Croatia': 48491,
#  'Cuba': 523203,
#  'Curacao': 1103,
#  'Cyprus': 2596,
#  'Czechia': 220159,
#  'Democratic Republic of Congo': None,
#  'Denmark': 76940,
#  'Djibouti': None,
#  'Dominica': None,
#  'Dominican Republic': 287355,
#  'Ecuador': 392492,
#  'Egypt': None,
#  'El Salvador': 13099,
#  'England': 557293,
#  'Estonia': 18299,
#  'Eswatini': None,
#  'Ethiopia': None,
#  'Faeroe Islands': None,
#  'Fiji': None,
#  'Finland': 314838,
#  'France': 1750217,
#  'Georgia': 54124,
#  'Germany': 2454441,
#  'Gibraltar': 258,
#  'Greece': 286237,
#  'Greenland': 43,
#  'Grenada': None,
#  'Guatemala': 407546,
#  'Guernsey': None,
#  'Guinea': None,
#  'Guinea-Bissau': None,
#  'Guyana': None,
#  'Haiti': None,
#  'Hong Kong': 287804,
#  'Hungary': None,
#  'Iceland': None,
#  'India': 41366193,
#  'Indonesia': None,
#  'Iran': 1490907,
#  'Iraq': None,
#  'Ireland': 62303,
#  'Isle of Man': 77,
#  'Israel': 74004,
#  'Italy': 3435534,
#  'Jamaica': 4296,
#  'Japan': 1348147,
#  'Jersey': None,
#  'Jordan': None,
#  'Kazakhstan': 92889,
#  'Kenya': 698938,
#  'Kosovo': 29244,
#  'Kuwait': None,
#  'Kyrgyzstan': 71184,
#  'Latvia': 36782,
#  'Lebanon': 94097,
#  'Libya': None,
#  'Liechtenstein': 543,
#  'Lithuania': 34361,
#  'Luxembourg': 19628,
#  'Macao': 10566,
#  'Malawi': 7452,
#  'Malaysia': 1099621,
#  'Maldives': 12934,
#  'Malta': 11628,
#  'Mexico': 4234320,
#  'Moldova': 39626,
#  'Mongolia': 13889,
#  'Montenegro': 73,
#  'Montserrat': None,
#  'Morocco': 51870,
#  'Mozambique': None,
#  'Myanmar': None,
#  'Namibia': None,
#  'Nepal': None,
#  'Netherlands': None,
#  'New Caledonia': None,
#  'New Zealand': 287940,
#  'Nicaragua': None,
#  'Niger': None,
#  'Nigeria': None,
#  'North Macedonia': None,
#  'Northern Ireland': 17650,
#  'Norway': 179620,
#  'Oman': None,
#  'Pakistan': None,
#  'Panama': 117978,
#  'Papua New Guinea': None,
#  'Paraguay': None,
#  'Peru': 796192,
#  'Philippines': 578732,
#  'Poland': 725127,
#  'Portugal': 551298,
#  'Qatar': 197681,
#  'Romania': 126638,
#  'Russia': 1406597,
#  'Rwanda': None,
#  'Saint Kitts and Nevis': None,
#  'Saint Lucia': None,
#  'Saint Vincent and the Grenadines': None,
#  'San Marino': None,
#  'Saudi Arabia': 943054,
#  'Scotland': 61402,
#  'Serbia': 4487,
#  'Sierra Leone': None,
#  'Singapore': 134420,
#  'Sint Maarten (Dutch part)': None,
#  'Slovakia': None,
#  'Slovenia': 19031,
#  'Solomon Islands': None,
#  'South Africa': 230224,
#  'South Korea': 1897739,
#  'South Sudan': None,
#  'Spain': 870414,
#  'Sri Lanka': 533007,
#  'Sudan': None,
#  'Suriname': 995,
#  'Sweden': None,
#  'Switzerland': 179589,
#  'Taiwan': 1386863,
#  'Tajikistan': None,
#  'Thailand': 2478382,
#  'Timor': None,
#  'Trinidad and Tobago': 13212,
#  'Tunisia': 59018,
#  'Turkey': 1043032,
#  'Uganda': None,
#  'Ukraine': 444598,
#  'United Arab Emirates': 187917,
#  'United Kingdom': 668850,
#  'United States': 4477995,
#  'Uruguay': 111610,
#  'Uzbekistan': None,
#  'Venezuela': None,
#  'Vietnam': 403300,
#  'Wales': 32505,
#  'Yemen': None,
#  'Zambia': 14333,
#  'Zimbabwe': 64964}

# %%
# Q8: How many vaccinations (across the world) were given on each date?

world_dict = {}
world_sum = 0

for row_idx in range(len(csv_data)):
    date = cell(row_idx, "date")
    daily_vacc = cell(row_idx, "daily_vaccinations")
    
    if date not in world_dict:
        world_dict[date] = None
            
    if world_dict[date] == None:
        daily_dict = daily_vaccinations_on(date)
        
        for key in daily_dict:
            if daily_dict[key] != None:
                world_sum += daily_dict[key]
        
        world_dict[date] = world_sum
    
    world_sum = 0
        
world_dict
# Out:
# {'01/25/2022': 21919087,
#  '01/26/2022': 22075204,
#  '01/27/2022': 19551593,
#  '01/28/2022': 19825492,
#  '01/29/2022': 14844495,
#  '01/30/2022': 13056961,
#  '01/31/2022': 15251126}

# %%
fully_dict = {}
    
for row_idx in range(len(csv_data)):
    date = cell(row_idx, "date")
    country = cell(row_idx, "country")
    fully_vacc = cell(row_idx, "people_fully_vaccinated")
    
    if country not in fully_dict:
        fully_dict[country] = None

    if fully_dict[country] == None:
        if fully_vacc != None:
            fully_dict[country] = date
        
fully_dict
# Out:
# {'Afghanistan': '01/26/2022',
#  'Albania': '01/30/2022',
#  'Angola': '01/28/2022',
#  'Anguilla': '01/28/2022',
#  'Antigua and Barbuda': '01/26/2022',
#  'Argentina': '01/25/2022',
#  'Armenia': '01/30/2022',
#  'Aruba': '01/25/2022',
#  'Austria': '01/28/2022',
#  'Azerbaijan': '01/25/2022',
#  'Bahamas': '01/26/2022',
#  'Bahrain': '01/25/2022',
#  'Bangladesh': '01/25/2022',
#  'Barbados': '01/25/2022',
#  'Belarus': '01/30/2022',
#  'Belgium': '01/25/2022',
#  'Belize': '01/28/2022',
#  'Bermuda': '01/28/2022',
#  'Bhutan': '01/30/2022',
#  'Bolivia': '01/25/2022',
#  'Bosnia and Herzegovina': '01/25/2022',
#  'Brazil': '01/25/2022',
#  'British Virgin Islands': '01/28/2022',
#  'Brunei': '01/28/2022',
#  'Bulgaria': '01/25/2022',
#  'Cambodia': '01/25/2022',
#  'Canada': '01/25/2022',
#  'Cayman Islands': '01/28/2022',
#  'Central African Republic': '01/31/2022',
#  'Chad': '01/30/2022',
#  'Chile': '01/25/2022',
#  'China': '01/28/2022',
#  'Colombia': '01/25/2022',
#  'Comoros': '01/27/2022',
#  'Costa Rica': '01/25/2022',
#  "Cote d'Ivoire": '01/27/2022',
#  'Croatia': '01/25/2022',
#  'Cuba': '01/25/2022',
#  'Curacao': '01/25/2022',
#  'Cyprus': '01/26/2022',
#  'Czechia': '01/25/2022',
#  'Democratic Republic of Congo': '01/27/2022',
#  'Denmark': '01/25/2022',
#  'Djibouti': '01/29/2022',
#  'Dominica': '01/26/2022',
#  'Dominican Republic': '01/25/2022',
#  'Ecuador': '01/25/2022',
#  'Egypt': '01/30/2022',
#  'El Salvador': '01/25/2022',
#  'England': '01/25/2022',
#  'Estonia': '01/25/2022',
#  'Eswatini': '01/25/2022',
#  'Ethiopia': '01/28/2022',
#  'Faeroe Islands': '01/25/2022',
#  'Fiji': '01/31/2022',
#  'Finland': '01/25/2022',
#  'France': '01/25/2022',
#  'Georgia': '01/25/2022',
#  'Germany': '01/25/2022',
#  'Gibraltar': '01/27/2022',
#  'Greece': '01/25/2022',
#  'Greenland': '01/25/2022',
#  'Grenada': '01/28/2022',
#  'Guatemala': '01/25/2022',
#  'Guernsey': None,
#  'Guinea': '01/31/2022',
#  'Guinea-Bissau': None,
#  'Guyana': '01/28/2022',
#  'Haiti': '01/30/2022',
#  'Hong Kong': '01/25/2022',
#  'Hungary': '01/25/2022',
#  'Iceland': '01/25/2022',
#  'India': '01/25/2022',
#  'Indonesia': '01/25/2022',
#  'Iran': '01/26/2022',
#  'Iraq': '01/26/2022',
#  'Ireland': '01/25/2022',
#  'Isle of Man': '01/25/2022',
#  'Israel': '01/25/2022',
#  'Italy': '01/25/2022',
#  'Jamaica': '01/25/2022',
#  'Japan': '01/25/2022',
#  'Jersey': '01/26/2022',
#  'Jordan': '01/25/2022',
#  'Kazakhstan': '01/25/2022',
#  'Kenya': '01/25/2022',
#  'Kosovo': '01/25/2022',
#  'Kuwait': '01/25/2022',
#  'Kyrgyzstan': None,
#  'Latvia': '01/25/2022',
#  'Lebanon': '01/25/2022',
#  'Libya': '01/25/2022',
#  'Liechtenstein': '01/25/2022',
#  'Lithuania': '01/25/2022',
#  'Luxembourg': None,
#  'Macao': '01/25/2022',
#  'Malawi': '01/25/2022',
#  'Malaysia': '01/25/2022',
#  'Maldives': '01/25/2022',
#  'Malta': '01/25/2022',
#  'Mexico': '01/25/2022',
#  'Moldova': '01/25/2022',
#  'Mongolia': '01/25/2022',
#  'Montenegro': '01/26/2022',
#  'Montserrat': '01/28/2022',
#  'Morocco': '01/25/2022',
#  'Mozambique': '01/28/2022',
#  'Myanmar': '01/29/2022',
#  'Namibia': '01/26/2022',
#  'Nepal': '01/31/2022',
#  'Netherlands': '01/29/2022',
#  'New Caledonia': '01/31/2022',
#  'New Zealand': '01/25/2022',
#  'Nicaragua': '01/26/2022',
#  'Niger': '01/31/2022',
#  'Nigeria': '01/29/2022',
#  'North Macedonia': '01/30/2022',
#  'Northern Ireland': '01/25/2022',
#  'Norway': '01/25/2022',
#  'Oman': '01/31/2022',
#  'Pakistan': '01/27/2022',
#  'Panama': '01/25/2022',
#  'Papua New Guinea': '01/31/2022',
#  'Paraguay': '01/28/2022',
#  'Peru': '01/25/2022',
#  'Philippines': '01/25/2022',
#  'Poland': '01/25/2022',
#  'Portugal': '01/25/2022',
#  'Qatar': None,
#  'Romania': '01/25/2022',
#  'Russia': '01/26/2022',
#  'Rwanda': '01/27/2022',
#  'Saint Kitts and Nevis': '01/26/2022',
#  'Saint Lucia': '01/28/2022',
#  'Saint Vincent and the Grenadines': '01/27/2022',
#  'San Marino': '01/30/2022',
#  'Saudi Arabia': '01/25/2022',
#  'Scotland': '01/25/2022',
#  'Serbia': '01/27/2022',
#  'Sierra Leone': '01/26/2022',
#  'Singapore': '01/25/2022',
#  'Sint Maarten (Dutch part)': '01/28/2022',
#  'Slovakia': '01/30/2022',
#  'Slovenia': '01/25/2022',
#  'Solomon Islands': '01/31/2022',
#  'South Africa': '01/26/2022',
#  'South Korea': '01/25/2022',
#  'South Sudan': '01/31/2022',
#  'Spain': '01/25/2022',
#  'Sri Lanka': '01/25/2022',
#  'Sudan': '01/25/2022',
#  'Suriname': '01/27/2022',
#  'Sweden': '01/30/2022',
#  'Switzerland': '01/25/2022',
#  'Taiwan': '01/25/2022',
#  'Tajikistan': '01/30/2022',
#  'Thailand': '01/25/2022',
#  'Timor': '01/25/2022',
#  'Trinidad and Tobago': '01/25/2022',
#  'Tunisia': '01/25/2022',
#  'Turkey': '01/25/2022',
#  'Uganda': '01/31/2022',
#  'Ukraine': '01/25/2022',
#  'United Arab Emirates': '01/25/2022',
#  'United Kingdom': '01/25/2022',
#  'United States': '01/25/2022',
#  'Uruguay': '01/25/2022',
#  'Uzbekistan': '01/30/2022',
#  'Venezuela': '01/28/2022',
#  'Vietnam': None,
#  'Wales': '01/25/2022',
#  'Yemen': '01/26/2022',
#  'Zambia': '01/25/2022',
#  'Zimbabwe': '01/25/2022'}

# %%
def get_number_of_days(start_date, end_date):
    
    """Gets the number of days between the start_date and end_date"""
    
    # The second argument is a format string to tell the function how to process the date string
    
    day1 = datetime.datetime.strptime(start_date, '%m/%d/%Y') 
    day2 = datetime.datetime.strptime(end_date, '%m/%d/%Y')
    
    delta = day2 - day1
    
    return delta.days

# %%
def most_recent_total(col_name, given_date):
    
    '''return a dictionary mapping each country to the most recent column value in the data 
    available by the given date; if no data is available, the value is None.'''
    
    country_info = {}
                
    for row_idx in range(len(csv_data)):
        country = cell(row_idx, "country")
        date = cell(row_idx, "date")
        col_value = cell(row_idx, col_name)
        date_diff = get_number_of_days(date, given_date)
                
        if country not in country_info:
            country_info[country] = col_value
        
        if col_value != None and date_diff >= 0:    
            country_info[country] = col_value

    return country_info

# %%
vaccination_stats = {}

for date in dates:
    daily_vax_dict = daily_vaccinations_on(date) # a dict mapping each country to number of daily_vaccinations on date
    total_vax_dict = most_recent_total('total_vaccinations', date) # a dict mapping each country to the most recent number of total_vaccinations on date
    people_vax_dict = most_recent_total('people_vaccinated', date) # a dict mapping each country to the most recent number of people_vaccinated on date
    fully_vax_dict = most_recent_total('people_fully_vaccinated', date) # a dict mapping each country to most recent number of people_fully_vaccinated on date
    total_booster_dict = most_recent_total('total_boosters', date) # a dict mapping each country to most recent number of total_boosters on date
    
    for country in countries:
        if country not in vaccination_stats:
            vaccination_stats[country] = {}
        
        vaccination_stats[country][date] = {}
        
        vaccination_stats[country][date]['country'] = country
        vaccination_stats[country][date]['date'] = date
        
        # TODO: fill in the rest of the dict to match the example above

        vaccination_stats[country][date]['daily_vaccinations'] = daily_vax_dict[country]
        vaccination_stats[country][date]['total_vaccinations'] = total_vax_dict[country]
        vaccination_stats[country][date]['people_vaccinated'] = people_vax_dict[country]
        vaccination_stats[country][date]['people_fully_vaccinated'] = fully_vax_dict[country]
        vaccination_stats[country][date]['total_boosters'] = total_booster_dict[country]
        vaccination_stats[country][date]['population'] = population[country]
        
vaccination_stats
# Out:
# {'Afghanistan': {'01/25/2022': {'country': 'Afghanistan',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 39822425},
#   '01/26/2022': {'country': 'Afghanistan',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 5074196,
#    'people_vaccinated': 4511372,
#    'people_fully_vaccinated': 3866279,
#    'total_boosters': None,
#    'population': 39822425},
#   '01/27/2022': {'country': 'Afghanistan',
#    'date': '01/27/2022',
#    'daily_vaccinations': 6868,
#    'total_vaccinations': 5081064,
#    'people_vaccinated': 4517380,
#    'people_fully_vaccinated': 3868832,
#    'total_boosters': None,
#    'population': 39822425},
#   '01/28/2022': {'country': 'Afghanistan',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 5081064,
#    'people_vaccinated': 4517380,
#    'people_fully_vaccinated': 3868832,
#    'total_boosters': None,
#    'population': 39822425},
#   '01/29/2022': {'country': 'Afghanistan',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 5081064,
#    'people_vaccinated': 4517380,
#    'people_fully_vaccinated': 3868832,
#    'total_boosters': None,
#    'population': 39822425},
#   '01/30/2022': {'country': 'Afghanistan',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 5081064,
#    'people_vaccinated': 4517380,
#    'people_fully_vaccinated': 3868832,
#    'total_boosters': None,
#    'population': 39822425},
#   '01/31/2022': {'country': 'Afghanistan',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 5125146,
#    'people_vaccinated': 4554648,
#    'people_fully_vaccinated': 3892831,
#    'total_boosters': None,
#    'population': 39822425}},
#  'Albania': {'01/25/2022': {'country': 'Albania',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2873046},
#   '01/26/2022': {'country': 'Albania',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2873046},
#   '01/27/2022': {'country': 'Albania',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2873046},
#   '01/28/2022': {'country': 'Albania',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2873046},
#   '01/29/2022': {'country': 'Albania',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2873046},
#   '01/30/2022': {'country': 'Albania',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2523683,
#    'people_vaccinated': 1210040,
#    'people_fully_vaccinated': 1111520,
#    'total_boosters': 202123,
#    'population': 2873046},
#   '01/31/2022': {'country': 'Albania',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2523683,
#    'people_vaccinated': 1210040,
#    'people_fully_vaccinated': 1111520,
#    'total_boosters': 202123,
#    'population': 2873046}},
#  'Angola': {'01/25/2022': {'country': 'Angola',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33934485},
#   '01/26/2022': {'country': 'Angola',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33934485},
#   '01/27/2022': {'country': 'Angola',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33934485},
#   '01/28/2022': {'country': 'Angola',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 14588435,
#    'people_vaccinated': 9713546,
#    'people_fully_vaccinated': 4731866,
#    'total_boosters': None,
#    'population': 33934485},
#   '01/29/2022': {'country': 'Angola',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 14588435,
#    'people_vaccinated': 9713546,
#    'people_fully_vaccinated': 4731866,
#    'total_boosters': None,
#    'population': 33934485},
#   '01/30/2022': {'country': 'Angola',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 14588435,
#    'people_vaccinated': 9713546,
#    'people_fully_vaccinated': 4731866,
#    'total_boosters': None,
#    'population': 33934485},
#   '01/31/2022': {'country': 'Angola',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 14588435,
#    'people_vaccinated': 9713546,
#    'people_fully_vaccinated': 4731866,
#    'total_boosters': None,
#    'population': 33934485}},
#  'Anguilla': {'01/25/2022': {'country': 'Anguilla',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 15126},
#   '01/26/2022': {'country': 'Anguilla',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 15126},
#   '01/27/2022': {'country': 'Anguilla',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 15126},
#   '01/28/2022': {'country': 'Anguilla',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 21449,
#    'people_vaccinated': 10193,
#    'people_fully_vaccinated': 9336,
#    'total_boosters': 1920,
#    'population': 15126},
#   '01/29/2022': {'country': 'Anguilla',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 21449,
#    'people_vaccinated': 10193,
#    'people_fully_vaccinated': 9336,
#    'total_boosters': 1920,
#    'population': 15126},
#   '01/30/2022': {'country': 'Anguilla',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 21449,
#    'people_vaccinated': 10193,
#    'people_fully_vaccinated': 9336,
#    'total_boosters': 1920,
#    'population': 15126},
#   '01/31/2022': {'country': 'Anguilla',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 21449,
#    'people_vaccinated': 10193,
#    'people_fully_vaccinated': 9336,
#    'total_boosters': 1920,
#    'population': 15126}},
#  'Antigua and Barbuda': {'01/25/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98726},
#   '01/26/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 123555,
#    'people_vaccinated': 63197,
#    'people_fully_vaccinated': 60358,
#    'total_boosters': None,
#    'population': 98726},
#   '01/27/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 123555,
#    'people_vaccinated': 63197,
#    'people_fully_vaccinated': 60358,
#    'total_boosters': None,
#    'population': 98726},
#   '01/28/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 123555,
#    'people_vaccinated': 63197,
#    'people_fully_vaccinated': 60358,
#    'total_boosters': None,
#    'population': 98726},
#   '01/29/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 123555,
#    'people_vaccinated': 63197,
#    'people_fully_vaccinated': 60358,
#    'total_boosters': None,
#    'population': 98726},
#   '01/30/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 123555,
#    'people_vaccinated': 63197,
#    'people_fully_vaccinated': 60358,
#    'total_boosters': None,
#    'population': 98726},
#   '01/31/2022': {'country': 'Antigua and Barbuda',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 123555,
#    'people_vaccinated': 63197,
#    'people_fully_vaccinated': 60358,
#    'total_boosters': None,
#    'population': 98726}},
#  'Argentina': {'01/25/2022': {'country': 'Argentina',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 85763224,
#    'people_vaccinated': 39445508,
#    'people_fully_vaccinated': 34414875,
#    'total_boosters': 11656958,
#    'population': 45605836},
#   '01/26/2022': {'country': 'Argentina',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 85763224,
#    'people_vaccinated': 39445508,
#    'people_fully_vaccinated': 34414875,
#    'total_boosters': 11656958,
#    'population': 45605836},
#   '01/27/2022': {'country': 'Argentina',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 86151950,
#    'people_vaccinated': 39494515,
#    'people_fully_vaccinated': 34497467,
#    'total_boosters': 11911737,
#    'population': 45605836},
#   '01/28/2022': {'country': 'Argentina',
#    'date': '01/28/2022',
#    'daily_vaccinations': 373468,
#    'total_vaccinations': 86525418,
#    'people_vaccinated': 39543211,
#    'people_fully_vaccinated': 34580056,
#    'total_boosters': 12151363,
#    'population': 45605836},
#   '01/29/2022': {'country': 'Argentina',
#    'date': '01/29/2022',
#    'daily_vaccinations': 371733,
#    'total_vaccinations': 86897151,
#    'people_vaccinated': 39586367,
#    'people_fully_vaccinated': 34652659,
#    'total_boosters': 12405024,
#    'population': 45605836},
#   '01/30/2022': {'country': 'Argentina',
#    'date': '01/30/2022',
#    'daily_vaccinations': 315886,
#    'total_vaccinations': 87213037,
#    'people_vaccinated': 39618863,
#    'people_fully_vaccinated': 34708999,
#    'total_boosters': 12630834,
#    'population': 45605836},
#   '01/31/2022': {'country': 'Argentina',
#    'date': '01/31/2022',
#    'daily_vaccinations': 363848,
#    'total_vaccinations': 87576885,
#    'people_vaccinated': 39663948,
#    'people_fully_vaccinated': 34788229,
#    'total_boosters': 12868208,
#    'population': 45605836}},
#  'Armenia': {'01/25/2022': {'country': 'Armenia',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2968277},
#   '01/26/2022': {'country': 'Armenia',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2968277},
#   '01/27/2022': {'country': 'Armenia',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2968277},
#   '01/28/2022': {'country': 'Armenia',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2968277},
#   '01/29/2022': {'country': 'Armenia',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 2968277},
#   '01/30/2022': {'country': 'Armenia',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1894651,
#    'people_vaccinated': 1045611,
#    'people_fully_vaccinated': 837694,
#    'total_boosters': None,
#    'population': 2968277},
#   '01/31/2022': {'country': 'Armenia',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1894651,
#    'people_vaccinated': 1045611,
#    'people_fully_vaccinated': 837694,
#    'total_boosters': None,
#    'population': 2968277}},
#  'Aruba': {'01/25/2022': {'country': 'Aruba',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 166117,
#    'people_vaccinated': 86444,
#    'people_fully_vaccinated': 79673,
#    'total_boosters': None,
#    'population': 107194},
#   '01/26/2022': {'country': 'Aruba',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 166117,
#    'people_vaccinated': 86444,
#    'people_fully_vaccinated': 79673,
#    'total_boosters': None,
#    'population': 107194},
#   '01/27/2022': {'country': 'Aruba',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 166235,
#    'people_vaccinated': 86509,
#    'people_fully_vaccinated': 79726,
#    'total_boosters': None,
#    'population': 107194},
#   '01/28/2022': {'country': 'Aruba',
#    'date': '01/28/2022',
#    'daily_vaccinations': 109,
#    'total_vaccinations': 166344,
#    'people_vaccinated': 86579,
#    'people_fully_vaccinated': 79765,
#    'total_boosters': None,
#    'population': 107194},
#   '01/29/2022': {'country': 'Aruba',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 166344,
#    'people_vaccinated': 86579,
#    'people_fully_vaccinated': 79765,
#    'total_boosters': None,
#    'population': 107194},
#   '01/30/2022': {'country': 'Aruba',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 166344,
#    'people_vaccinated': 86579,
#    'people_fully_vaccinated': 79765,
#    'total_boosters': None,
#    'population': 107194},
#   '01/31/2022': {'country': 'Aruba',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 166440,
#    'people_vaccinated': 86627,
#    'people_fully_vaccinated': 79813,
#    'total_boosters': None,
#    'population': 107194}},
#  'Austria': {'01/25/2022': {'country': 'Austria',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9043061},
#   '01/26/2022': {'country': 'Austria',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9043061},
#   '01/27/2022': {'country': 'Austria',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9043061},
#   '01/28/2022': {'country': 'Austria',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 17601412,
#    'people_vaccinated': 6761872,
#    'people_fully_vaccinated': 6470286,
#    'total_boosters': 4717848,
#    'population': 9043061},
#   '01/29/2022': {'country': 'Austria',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 17601412,
#    'people_vaccinated': 6761872,
#    'people_fully_vaccinated': 6470286,
#    'total_boosters': 4717848,
#    'population': 9043061},
#   '01/30/2022': {'country': 'Austria',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 17601412,
#    'people_vaccinated': 6761872,
#    'people_fully_vaccinated': 6470286,
#    'total_boosters': 4717848,
#    'population': 9043061},
#   '01/31/2022': {'country': 'Austria',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 17601412,
#    'people_vaccinated': 6761872,
#    'people_fully_vaccinated': 6470286,
#    'total_boosters': 4717848,
#    'population': 9043061}},
#  'Azerbaijan': {'01/25/2022': {'country': 'Azerbaijan',
#    'date': '01/25/2022',
#    'daily_vaccinations': 31667,
#    'total_vaccinations': 11845510,
#    'people_vaccinated': 5217380,
#    'people_fully_vaccinated': 4732155,
#    'total_boosters': 1895975,
#    'population': 10222990},
#   '01/26/2022': {'country': 'Azerbaijan',
#    'date': '01/26/2022',
#    'daily_vaccinations': 30563,
#    'total_vaccinations': 11876073,
#    'people_vaccinated': 5220001,
#    'people_fully_vaccinated': 4734704,
#    'total_boosters': 1921368,
#    'population': 10222990},
#   '01/27/2022': {'country': 'Azerbaijan',
#    'date': '01/27/2022',
#    'daily_vaccinations': 29515,
#    'total_vaccinations': 11905588,
#    'people_vaccinated': 5222566,
#    'people_fully_vaccinated': 4736905,
#    'total_boosters': 1946117,
#    'population': 10222990},
#   '01/28/2022': {'country': 'Azerbaijan',
#    'date': '01/28/2022',
#    'daily_vaccinations': 30887,
#    'total_vaccinations': 11936475,
#    'people_vaccinated': 5225069,
#    'people_fully_vaccinated': 4738970,
#    'total_boosters': 1972436,
#    'population': 10222990},
#   '01/29/2022': {'country': 'Azerbaijan',
#    'date': '01/29/2022',
#    'daily_vaccinations': 34546,
#    'total_vaccinations': 11971021,
#    'people_vaccinated': 5228014,
#    'people_fully_vaccinated': 4740859,
#    'total_boosters': 2002148,
#    'population': 10222990},
#   '01/30/2022': {'country': 'Azerbaijan',
#    'date': '01/30/2022',
#    'daily_vaccinations': 29728,
#    'total_vaccinations': 12000749,
#    'people_vaccinated': 5230388,
#    'people_fully_vaccinated': 4742169,
#    'total_boosters': 2028192,
#    'population': 10222990},
#   '01/31/2022': {'country': 'Azerbaijan',
#    'date': '01/31/2022',
#    'daily_vaccinations': 18,
#    'total_vaccinations': 12000767,
#    'people_vaccinated': 5230388,
#    'people_fully_vaccinated': 4742174,
#    'total_boosters': 2028205,
#    'population': 10222990}},
#  'Bahamas': {'01/25/2022': {'country': 'Bahamas',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 396909},
#   '01/26/2022': {'country': 'Bahamas',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 318916,
#    'people_vaccinated': 160505,
#    'people_fully_vaccinated': 151520,
#    'total_boosters': 18037,
#    'population': 396909},
#   '01/27/2022': {'country': 'Bahamas',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 318916,
#    'people_vaccinated': 160505,
#    'people_fully_vaccinated': 151520,
#    'total_boosters': 18037,
#    'population': 396909},
#   '01/28/2022': {'country': 'Bahamas',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 318916,
#    'people_vaccinated': 160505,
#    'people_fully_vaccinated': 151520,
#    'total_boosters': 18037,
#    'population': 396909},
#   '01/29/2022': {'country': 'Bahamas',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 318916,
#    'people_vaccinated': 160505,
#    'people_fully_vaccinated': 151520,
#    'total_boosters': 18037,
#    'population': 396909},
#   '01/30/2022': {'country': 'Bahamas',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 318916,
#    'people_vaccinated': 160505,
#    'people_fully_vaccinated': 151520,
#    'total_boosters': 18037,
#    'population': 396909},
#   '01/31/2022': {'country': 'Bahamas',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 318916,
#    'people_vaccinated': 160505,
#    'people_fully_vaccinated': 151520,
#    'total_boosters': 18037,
#    'population': 396909}},
#  'Bahrain': {'01/25/2022': {'country': 'Bahrain',
#    'date': '01/25/2022',
#    'daily_vaccinations': 8622,
#    'total_vaccinations': 3341262,
#    'people_vaccinated': 1219265,
#    'people_fully_vaccinated': 1192261,
#    'total_boosters': 929736,
#    'population': 1748265},
#   '01/26/2022': {'country': 'Bahrain',
#    'date': '01/26/2022',
#    'daily_vaccinations': 2716,
#    'total_vaccinations': 3343978,
#    'people_vaccinated': 1219977,
#    'people_fully_vaccinated': 1192408,
#    'total_boosters': 931593,
#    'population': 1748265},
#   '01/27/2022': {'country': 'Bahrain',
#    'date': '01/27/2022',
#    'daily_vaccinations': 2827,
#    'total_vaccinations': 3346805,
#    'people_vaccinated': 1220718,
#    'people_fully_vaccinated': 1192572,
#    'total_boosters': 933515,
#    'population': 1748265},
#   '01/28/2022': {'country': 'Bahrain',
#    'date': '01/28/2022',
#    'daily_vaccinations': 2090,
#    'total_vaccinations': 3348895,
#    'people_vaccinated': 1221632,
#    'people_fully_vaccinated': 1192627,
#    'total_boosters': 934636,
#    'population': 1748265},
#   '01/29/2022': {'country': 'Bahrain',
#    'date': '01/29/2022',
#    'daily_vaccinations': 1750,
#    'total_vaccinations': 3350645,
#    'people_vaccinated': 1222439,
#    'people_fully_vaccinated': 1192679,
#    'total_boosters': 935527,
#    'population': 1748265},
#   '01/30/2022': {'country': 'Bahrain',
#    'date': '01/30/2022',
#    'daily_vaccinations': 4100,
#    'total_vaccinations': 3354745,
#    'people_vaccinated': 1223635,
#    'people_fully_vaccinated': 1193541,
#    'total_boosters': 937569,
#    'population': 1748265},
#   '01/31/2022': {'country': 'Bahrain',
#    'date': '01/31/2022',
#    'daily_vaccinations': 2272,
#    'total_vaccinations': 3357017,
#    'people_vaccinated': 1223859,
#    'people_fully_vaccinated': 1193959,
#    'total_boosters': 939199,
#    'population': 1748265}},
#  'Bangladesh': {'01/25/2022': {'country': 'Bangladesh',
#    'date': '01/25/2022',
#    'daily_vaccinations': 1119638,
#    'total_vaccinations': 155002117,
#    'people_vaccinated': 94703296,
#    'people_fully_vaccinated': 59108539,
#    'total_boosters': 1190282,
#    'population': 166312179},
#   '01/26/2022': {'country': 'Bangladesh',
#    'date': '01/26/2022',
#    'daily_vaccinations': 1414487,
#    'total_vaccinations': 156416604,
#    'people_vaccinated': 95440321,
#    'people_fully_vaccinated': 59711538,
#    'total_boosters': 1264745,
#    'population': 166312179},
#   '01/27/2022': {'country': 'Bangladesh',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 156416604,
#    'people_vaccinated': 95440321,
#    'people_fully_vaccinated': 59711538,
#    'total_boosters': 1264745,
#    'population': 166312179},
#   '01/28/2022': {'country': 'Bangladesh',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 156416604,
#    'people_vaccinated': 95440321,
#    'people_fully_vaccinated': 59711538,
#    'total_boosters': 1264745,
#    'population': 166312179},
#   '01/29/2022': {'country': 'Bangladesh',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 156416604,
#    'people_vaccinated': 95440321,
#    'people_fully_vaccinated': 59711538,
#    'total_boosters': 1264745,
#    'population': 166312179},
#   '01/30/2022': {'country': 'Bangladesh',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 156416604,
#    'people_vaccinated': 95440321,
#    'people_fully_vaccinated': 59711538,
#    'total_boosters': 1264745,
#    'population': 166312179},
#   '01/31/2022': {'country': 'Bangladesh',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 156416604,
#    'people_vaccinated': 95440321,
#    'people_fully_vaccinated': 59711538,
#    'total_boosters': 1264745,
#    'population': 166312179}},
#  'Barbados': {'01/25/2022': {'country': 'Barbados',
#    'date': '01/25/2022',
#    'daily_vaccinations': 222,
#    'total_vaccinations': 304941,
#    'people_vaccinated': 158242,
#    'people_fully_vaccinated': 146699,
#    'total_boosters': None,
#    'population': 287709},
#   '01/26/2022': {'country': 'Barbados',
#    'date': '01/26/2022',
#    'daily_vaccinations': 239,
#    'total_vaccinations': 305180,
#    'people_vaccinated': 158358,
#    'people_fully_vaccinated': 146822,
#    'total_boosters': None,
#    'population': 287709},
#   '01/27/2022': {'country': 'Barbados',
#    'date': '01/27/2022',
#    'daily_vaccinations': 194,
#    'total_vaccinations': 305374,
#    'people_vaccinated': 158463,
#    'people_fully_vaccinated': 146911,
#    'total_boosters': None,
#    'population': 287709},
#   '01/28/2022': {'country': 'Barbados',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 305374,
#    'people_vaccinated': 158463,
#    'people_fully_vaccinated': 146911,
#    'total_boosters': None,
#    'population': 287709},
#   '01/29/2022': {'country': 'Barbados',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 305374,
#    'people_vaccinated': 158463,
#    'people_fully_vaccinated': 146911,
#    'total_boosters': None,
#    'population': 287709},
#   '01/30/2022': {'country': 'Barbados',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 305374,
#    'people_vaccinated': 158463,
#    'people_fully_vaccinated': 146911,
#    'total_boosters': None,
#    'population': 287709},
#   '01/31/2022': {'country': 'Barbados',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 305374,
#    'people_vaccinated': 158463,
#    'people_fully_vaccinated': 146911,
#    'total_boosters': None,
#    'population': 287709}},
#  'Belarus': {'01/25/2022': {'country': 'Belarus',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9442839},
#   '01/26/2022': {'country': 'Belarus',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9442839},
#   '01/27/2022': {'country': 'Belarus',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9442839},
#   '01/28/2022': {'country': 'Belarus',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9442839},
#   '01/29/2022': {'country': 'Belarus',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 9442839},
#   '01/30/2022': {'country': 'Belarus',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 10028295,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 4233740,
#    'total_boosters': None,
#    'population': 9442839},
#   '01/31/2022': {'country': 'Belarus',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 10028295,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 4233740,
#    'total_boosters': None,
#    'population': 9442839}},
#  'Belgium': {'01/25/2022': {'country': 'Belgium',
#    'date': '01/25/2022',
#    'daily_vaccinations': 44335,
#    'total_vaccinations': 23955357,
#    'people_vaccinated': 9107406,
#    'people_fully_vaccinated': 8858389,
#    'total_boosters': 6416564,
#    'population': 11632221},
#   '01/26/2022': {'country': 'Belgium',
#    'date': '01/26/2022',
#    'daily_vaccinations': 61488,
#    'total_vaccinations': 24016845,
#    'people_vaccinated': 9125269,
#    'people_fully_vaccinated': 8861621,
#    'total_boosters': 6457014,
#    'population': 11632221},
#   '01/27/2022': {'country': 'Belgium',
#    'date': '01/27/2022',
#    'daily_vaccinations': 42940,
#    'total_vaccinations': 24059785,
#    'people_vaccinated': 9128092,
#    'people_fully_vaccinated': 8863018,
#    'total_boosters': 6495754,
#    'population': 11632221},
#   '01/28/2022': {'country': 'Belgium',
#    'date': '01/28/2022',
#    'daily_vaccinations': 45869,
#    'total_vaccinations': 24105654,
#    'people_vaccinated': 9130726,
#    'people_fully_vaccinated': 8864669,
#    'total_boosters': 6537380,
#    'population': 11632221},
#   '01/29/2022': {'country': 'Belgium',
#    'date': '01/29/2022',
#    'daily_vaccinations': 46036,
#    'total_vaccinations': 24151690,
#    'people_vaccinated': 9148174,
#    'people_fully_vaccinated': 8873836,
#    'total_boosters': 6556811,
#    'population': 11632221},
#   '01/30/2022': {'country': 'Belgium',
#    'date': '01/30/2022',
#    'daily_vaccinations': 6239,
#    'total_vaccinations': 24157929,
#    'people_vaccinated': 9150562,
#    'people_fully_vaccinated': 8875753,
#    'total_boosters': 6558745,
#    'population': 11632221},
#   '01/31/2022': {'country': 'Belgium',
#    'date': '01/31/2022',
#    'daily_vaccinations': 24295,
#    'total_vaccinations': 24182224,
#    'people_vaccinated': 9152229,
#    'people_fully_vaccinated': 8876879,
#    'total_boosters': 6580264,
#    'population': 11632221}},
#  'Belize': {'01/25/2022': {'country': 'Belize',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 404916},
#   '01/26/2022': {'country': 'Belize',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 404916},
#   '01/27/2022': {'country': 'Belize',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 404916},
#   '01/28/2022': {'country': 'Belize',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 445691,
#    'people_vaccinated': 232515,
#    'people_fully_vaccinated': 203237,
#    'total_boosters': None,
#    'population': 404916},
#   '01/29/2022': {'country': 'Belize',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 445691,
#    'people_vaccinated': 232515,
#    'people_fully_vaccinated': 203237,
#    'total_boosters': None,
#    'population': 404916},
#   '01/30/2022': {'country': 'Belize',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 445691,
#    'people_vaccinated': 232515,
#    'people_fully_vaccinated': 203237,
#    'total_boosters': None,
#    'population': 404916},
#   '01/31/2022': {'country': 'Belize',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 445691,
#    'people_vaccinated': 232515,
#    'people_fully_vaccinated': 203237,
#    'total_boosters': None,
#    'population': 404916}},
#  'Bermuda': {'01/25/2022': {'country': 'Bermuda',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 62094},
#   '01/26/2022': {'country': 'Bermuda',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 62094},
#   '01/27/2022': {'country': 'Bermuda',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 62094},
#   '01/28/2022': {'country': 'Bermuda',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 120535,
#    'people_vaccinated': 46695,
#    'people_fully_vaccinated': 45863,
#    'total_boosters': 27977,
#    'population': 62094},
#   '01/29/2022': {'country': 'Bermuda',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 120535,
#    'people_vaccinated': 46695,
#    'people_fully_vaccinated': 45863,
#    'total_boosters': 27977,
#    'population': 62094},
#   '01/30/2022': {'country': 'Bermuda',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 120535,
#    'people_vaccinated': 46695,
#    'people_fully_vaccinated': 45863,
#    'total_boosters': 27977,
#    'population': 62094},
#   '01/31/2022': {'country': 'Bermuda',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 120535,
#    'people_vaccinated': 46695,
#    'people_fully_vaccinated': 45863,
#    'total_boosters': 27977,
#    'population': 62094}},
#  'Bhutan': {'01/25/2022': {'country': 'Bhutan',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 779889},
#   '01/26/2022': {'country': 'Bhutan',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 779889},
#   '01/27/2022': {'country': 'Bhutan',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 779889},
#   '01/28/2022': {'country': 'Bhutan',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 779889},
#   '01/29/2022': {'country': 'Bhutan',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 779889},
#   '01/30/2022': {'country': 'Bhutan',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1435774,
#    'people_vaccinated': 593980,
#    'people_fully_vaccinated': 570751,
#    'total_boosters': 351962,
#    'population': 779889},
#   '01/31/2022': {'country': 'Bhutan',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1435774,
#    'people_vaccinated': 593980,
#    'people_fully_vaccinated': 570751,
#    'total_boosters': 351962,
#    'population': 779889}},
#  'Bolivia': {'01/25/2022': {'country': 'Bolivia',
#    'date': '01/25/2022',
#    'daily_vaccinations': 70812,
#    'total_vaccinations': 11601193,
#    'people_vaccinated': 6648054,
#    'people_fully_vaccinated': 5112190,
#    'total_boosters': 835910,
#    'population': 11832385},
#   '01/26/2022': {'country': 'Bolivia',
#    'date': '01/26/2022',
#    'daily_vaccinations': 57570,
#    'total_vaccinations': 11658763,
#    'people_vaccinated': 6664808,
#    'people_fully_vaccinated': 5143396,
#    'total_boosters': 845520,
#    'population': 11832385},
#   '01/27/2022': {'country': 'Bolivia',
#    'date': '01/27/2022',
#    'daily_vaccinations': 50562,
#    'total_vaccinations': 11709325,
#    'people_vaccinated': 6679305,
#    'people_fully_vaccinated': 5171346,
#    'total_boosters': 853635,
#    'population': 11832385},
#   '01/28/2022': {'country': 'Bolivia',
#    'date': '01/28/2022',
#    'daily_vaccinations': 54529,
#    'total_vaccinations': 11763854,
#    'people_vaccinated': 6694190,
#    'people_fully_vaccinated': 5201566,
#    'total_boosters': 863059,
#    'population': 11832385},
#   '01/29/2022': {'country': 'Bolivia',
#    'date': '01/29/2022',
#    'daily_vaccinations': 23699,
#    'total_vaccinations': 11787553,
#    'people_vaccinated': 6701069,
#    'people_fully_vaccinated': 5213649,
#    'total_boosters': 867796,
#    'population': 11832385},
#   '01/30/2022': {'country': 'Bolivia',
#    'date': '01/30/2022',
#    'daily_vaccinations': 6546,
#    'total_vaccinations': 11794099,
#    'people_vaccinated': 6703310,
#    'people_fully_vaccinated': 5216544,
#    'total_boosters': 869406,
#    'population': 11832385},
#   '01/31/2022': {'country': 'Bolivia',
#    'date': '01/31/2022',
#    'daily_vaccinations': 66683,
#    'total_vaccinations': 11860782,
#    'people_vaccinated': 6726944,
#    'people_fully_vaccinated': 5249825,
#    'total_boosters': 879174,
#    'population': 11832385}},
#  'Bosnia and Herzegovina': {'01/25/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': 939775,
#    'people_fully_vaccinated': 842954,
#    'total_boosters': 120530,
#    'population': 3263734},
#   '01/26/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': 939775,
#    'people_fully_vaccinated': 842954,
#    'total_boosters': 120530,
#    'population': 3263734},
#   '01/27/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': 939775,
#    'people_fully_vaccinated': 842954,
#    'total_boosters': 120530,
#    'population': 3263734},
#   '01/28/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': 939775,
#    'people_fully_vaccinated': 842954,
#    'total_boosters': 120530,
#    'population': 3263734},
#   '01/29/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1924950,
#    'people_vaccinated': 943394,
#    'people_fully_vaccinated': 846080,
#    'total_boosters': 120530,
#    'population': 3263734},
#   '01/30/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1924950,
#    'people_vaccinated': 943394,
#    'people_fully_vaccinated': 846080,
#    'total_boosters': 120530,
#    'population': 3263734},
#   '01/31/2022': {'country': 'Bosnia and Herzegovina',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 1924950,
#    'people_vaccinated': 943394,
#    'people_fully_vaccinated': 846080,
#    'total_boosters': 120530,
#    'population': 3263734}},
#  'Brazil': {'01/25/2022': {'country': 'Brazil',
#    'date': '01/25/2022',
#    'daily_vaccinations': 1109088,
#    'total_vaccinations': 355987219,
#    'people_vaccinated': 168546490,
#    'people_fully_vaccinated': 149165531,
#    'total_boosters': 43260640,
#    'population': 213992450},
#   '01/26/2022': {'country': 'Brazil',
#    'date': '01/26/2022',
#    'daily_vaccinations': 1145771,
#    'total_vaccinations': 357132990,
#    'people_vaccinated': 168921071,
#    'people_fully_vaccinated': 149273731,
#    'total_boosters': 43930017,
#    'population': 213992450},
#   '01/27/2022': {'country': 'Brazil',
#    'date': '01/27/2022',
#    'daily_vaccinations': 1656940,
#    'total_vaccinations': 358789930,
#    'people_vaccinated': 169261105,
#    'people_fully_vaccinated': 149542396,
#    'total_boosters': 44986684,
#    'population': 213992450},
#   '01/28/2022': {'country': 'Brazil',
#    'date': '01/28/2022',
#    'daily_vaccinations': 1702800,
#    'total_vaccinations': 360492730,
#    'people_vaccinated': 169619416,
#    'people_fully_vaccinated': 149714068,
#    'total_boosters': 46174206,
#    'population': 213992450},
#   '01/29/2022': {'country': 'Brazil',
#    'date': '01/29/2022',
#    'daily_vaccinations': 672466,
#    'total_vaccinations': 361165196,
#    'people_vaccinated': 169825847,
#    'people_fully_vaccinated': 149779557,
#    'total_boosters': 46576117,
#    'population': 213992450},
#   '01/30/2022': {'country': 'Brazil',
#    'date': '01/30/2022',
#    'daily_vaccinations': 144483,
#    'total_vaccinations': 361309679,
#    'people_vaccinated': 169865538,
#    'people_fully_vaccinated': 149793528,
#    'total_boosters': 46667050,
#    'population': 213992450},
#   '01/31/2022': {'country': 'Brazil',
#    'date': '01/31/2022',
#    'daily_vaccinations': 1193530,
#    'total_vaccinations': 362503209,
#    'people_vaccinated': 170322125,
#    'people_fully_vaccinated': 149930855,
#    'total_boosters': 47268419,
#    'population': 213992450}},
#  'British Virgin Islands': {'01/25/2022': {'country': 'British Virgin Islands',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 30423},
#   '01/26/2022': {'country': 'British Virgin Islands',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 30423},
#   '01/27/2022': {'country': 'British Virgin Islands',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 30423},
#   '01/28/2022': {'country': 'British Virgin Islands',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 36330,
#    'people_vaccinated': 18753,
#    'people_fully_vaccinated': 17215,
#    'total_boosters': None,
#    'population': 30423},
#   '01/29/2022': {'country': 'British Virgin Islands',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 36330,
#    'people_vaccinated': 18753,
#    'people_fully_vaccinated': 17215,
#    'total_boosters': None,
#    'population': 30423},
#   '01/30/2022': {'country': 'British Virgin Islands',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 36330,
#    'people_vaccinated': 18753,
#    'people_fully_vaccinated': 17215,
#    'total_boosters': None,
#    'population': 30423},
#   '01/31/2022': {'country': 'British Virgin Islands',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 36330,
#    'people_vaccinated': 18753,
#    'people_fully_vaccinated': 17215,
#    'total_boosters': None,
#    'population': 30423}},
#  'Brunei': {'01/25/2022': {'country': 'Brunei',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 441538},
#   '01/26/2022': {'country': 'Brunei',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 441538},
#   '01/27/2022': {'country': 'Brunei',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 441538},
#   '01/28/2022': {'country': 'Brunei',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 979285,
#    'people_vaccinated': 407042,
#    'people_fully_vaccinated': 403385,
#    'total_boosters': None,
#    'population': 441538},
#   '01/29/2022': {'country': 'Brunei',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 979285,
#    'people_vaccinated': 407042,
#    'people_fully_vaccinated': 403385,
#    'total_boosters': None,
#    'population': 441538},
#   '01/30/2022': {'country': 'Brunei',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 979285,
#    'people_vaccinated': 407042,
#    'people_fully_vaccinated': 403385,
#    'total_boosters': None,
#    'population': 441538},
#   '01/31/2022': {'country': 'Brunei',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 979285,
#    'people_vaccinated': 407042,
#    'people_fully_vaccinated': 403385,
#    'total_boosters': None,
#    'population': 441538}},
#  'Bulgaria': {'01/25/2022': {'country': 'Bulgaria',
#    'date': '01/25/2022',
#    'daily_vaccinations': 10657,
#    'total_vaccinations': 4114896,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1980511,
#    'total_boosters': 580808,
#    'population': 6896487},
#   '01/26/2022': {'country': 'Bulgaria',
#    'date': '01/26/2022',
#    'daily_vaccinations': 11848,
#    'total_vaccinations': 4126744,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1983763,
#    'total_boosters': 588403,
#    'population': 6896487},
#   '01/27/2022': {'country': 'Bulgaria',
#    'date': '01/27/2022',
#    'daily_vaccinations': 12621,
#    'total_vaccinations': 4139365,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1987545,
#    'total_boosters': 596235,
#    'population': 6896487},
#   '01/28/2022': {'country': 'Bulgaria',
#    'date': '01/28/2022',
#    'daily_vaccinations': 12787,
#    'total_vaccinations': 4152152,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1991648,
#    'total_boosters': 603840,
#    'population': 6896487},
#   '01/29/2022': {'country': 'Bulgaria',
#    'date': '01/29/2022',
#    'daily_vaccinations': 3467,
#    'total_vaccinations': 4155619,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1992848,
#    'total_boosters': 605792,
#    'population': 6896487},
#   '01/30/2022': {'country': 'Bulgaria',
#    'date': '01/30/2022',
#    'daily_vaccinations': 1901,
#    'total_vaccinations': 4157520,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1993529,
#    'total_boosters': 606917,
#    'population': 6896487},
#   '01/31/2022': {'country': 'Bulgaria',
#    'date': '01/31/2022',
#    'daily_vaccinations': 7958,
#    'total_vaccinations': 4165478,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1996484,
#    'total_boosters': 611314,
#    'population': 6896487}},
#  'Cambodia': {'01/25/2022': {'country': 'Cambodia',
#    'date': '01/25/2022',
#    'daily_vaccinations': 117730,
#    'total_vaccinations': 32800712,
#    'people_vaccinated': 14342352,
#    'people_fully_vaccinated': 13743612,
#    'total_boosters': 5767899,
#    'population': 16946049},
#   '01/26/2022': {'country': 'Cambodia',
#    'date': '01/26/2022',
#    'daily_vaccinations': 94384,
#    'total_vaccinations': 32895096,
#    'people_vaccinated': 14345304,
#    'people_fully_vaccinated': 13747904,
#    'total_boosters': 5855039,
#    'population': 16946049},
#   '01/27/2022': {'country': 'Cambodia',
#    'date': '01/27/2022',
#    'daily_vaccinations': 79450,
#    'total_vaccinations': 32974546,
#    'people_vaccinated': 14348054,
#    'people_fully_vaccinated': 13751678,
#    'total_boosters': 5927965,
#    'population': 16946049},
#   '01/28/2022': {'country': 'Cambodia',
#    'date': '01/28/2022',
#    'daily_vaccinations': 76206,
#    'total_vaccinations': 33050752,
#    'people_vaccinated': 14350592,
#    'people_fully_vaccinated': 13756300,
#    'total_boosters': 5997011,
#    'population': 16946049},
#   '01/29/2022': {'country': 'Cambodia',
#    'date': '01/29/2022',
#    'daily_vaccinations': 47089,
#    'total_vaccinations': 33097841,
#    'people_vaccinated': 14351805,
#    'people_fully_vaccinated': 13758000,
#    'total_boosters': 6041187,
#    'population': 16946049},
#   '01/30/2022': {'country': 'Cambodia',
#    'date': '01/30/2022',
#    'daily_vaccinations': 23476,
#    'total_vaccinations': 33121317,
#    'people_vaccinated': 14352541,
#    'people_fully_vaccinated': 13759069,
#    'total_boosters': 6062858,
#    'population': 16946049},
#   '01/31/2022': {'country': 'Cambodia',
#    'date': '01/31/2022',
#    'daily_vaccinations': 23460,
#    'total_vaccinations': 33144777,
#    'people_vaccinated': 14353621,
#    'people_fully_vaccinated': 13760630,
#    'total_boosters': 6083677,
#    'population': 16946049}},
#  'Canada': {'01/25/2022': {'country': 'Canada',
#    'date': '01/25/2022',
#    'daily_vaccinations': 334789,
#    'total_vaccinations': 76588007,
#    'people_vaccinated': 32236332,
#    'people_fully_vaccinated': 29903275,
#    'total_boosters': 14448400,
#    'population': 38067582},
#   '01/26/2022': {'country': 'Canada',
#    'date': '01/26/2022',
#    'daily_vaccinations': 263476,
#    'total_vaccinations': 76851483,
#    'people_vaccinated': 32253251,
#    'people_fully_vaccinated': 29940348,
#    'total_boosters': 14657884,
#    'population': 38067582},
#   '01/27/2022': {'country': 'Canada',
#    'date': '01/27/2022',
#    'daily_vaccinations': 259273,
#    'total_vaccinations': 77110756,
#    'people_vaccinated': 32271463,
#    'people_fully_vaccinated': 29980491,
#    'total_boosters': 14858802,
#    'population': 38067582},
#   '01/28/2022': {'country': 'Canada',
#    'date': '01/28/2022',
#    'daily_vaccinations': 257333,
#    'total_vaccinations': 77368089,
#    'people_vaccinated': 32290019,
#    'people_fully_vaccinated': 30021580,
#    'total_boosters': 15056490,
#    'population': 38067582},
#   '01/29/2022': {'country': 'Canada',
# ...
#    'date': '01/26/2022',
#    'daily_vaccinations': 754708,
#    'total_vaccinations': 539909587,
#    'people_vaccinated': 250187320,
#    'people_fully_vaccinated': 211266984,
#    'total_boosters': 87997560,
#    'population': 332009030},
#   '01/27/2022': {'country': 'United States',
#    'date': '01/27/2022',
#    'daily_vaccinations': 749316,
#    'total_vaccinations': 540658903,
#    'people_vaccinated': 250384064,
#    'people_fully_vaccinated': 211434700,
#    'total_boosters': 88379500,
#    'population': 332009030},
#   '01/28/2022': {'country': 'United States',
#    'date': '01/28/2022',
#    'daily_vaccinations': 905850,
#    'total_vaccinations': 541564753,
#    'people_vaccinated': 250611953,
#    'people_fully_vaccinated': 211634846,
#    'total_boosters': 88852560,
#    'population': 332009030},
#   '01/29/2022': {'country': 'United States',
#    'date': '01/29/2022',
#    'daily_vaccinations': 448115,
#    'total_vaccinations': 542012868,
#    'people_vaccinated': 250733205,
#    'people_fully_vaccinated': 211741269,
#    'total_boosters': 89070593,
#    'population': 332009030},
#   '01/30/2022': {'country': 'United States',
#    'date': '01/30/2022',
#    'daily_vaccinations': 254541,
#    'total_vaccinations': 542267409,
#    'people_vaccinated': 250805239,
#    'people_fully_vaccinated': 211805801,
#    'total_boosters': 89187391,
#    'population': 332009030},
#   '01/31/2022': {'country': 'United States',
#    'date': '01/31/2022',
#    'daily_vaccinations': 600555,
#    'total_vaccinations': 542867964,
#    'people_vaccinated': 250964826,
#    'people_fully_vaccinated': 211957212,
#    'total_boosters': 89474239,
#    'population': 332009030}},
#  'Uruguay': {'01/25/2022': {'country': 'Uruguay',
#    'date': '01/25/2022',
#    'daily_vaccinations': 20374,
#    'total_vaccinations': 7336614,
#    'people_vaccinated': 2867788,
#    'people_fully_vaccinated': 2690283,
#    'total_boosters': 1778543,
#    'population': 3485127},
#   '01/26/2022': {'country': 'Uruguay',
#    'date': '01/26/2022',
#    'daily_vaccinations': 23237,
#    'total_vaccinations': 7359851,
#    'people_vaccinated': 2878491,
#    'people_fully_vaccinated': 2690976,
#    'total_boosters': 1790384,
#    'population': 3485127},
#   '01/27/2022': {'country': 'Uruguay',
#    'date': '01/27/2022',
#    'daily_vaccinations': 24215,
#    'total_vaccinations': 7384066,
#    'people_vaccinated': 2888879,
#    'people_fully_vaccinated': 2691340,
#    'total_boosters': 1803847,
#    'population': 3485127},
#   '01/28/2022': {'country': 'Uruguay',
#    'date': '01/28/2022',
#    'daily_vaccinations': 25471,
#    'total_vaccinations': 7409537,
#    'people_vaccinated': 2893543,
#    'people_fully_vaccinated': 2692006,
#    'total_boosters': 1823988,
#    'population': 3485127},
#   '01/29/2022': {'country': 'Uruguay',
#    'date': '01/29/2022',
#    'daily_vaccinations': 127,
#    'total_vaccinations': 7409664,
#    'people_vaccinated': 2893559,
#    'people_fully_vaccinated': 2692021,
#    'total_boosters': 1824084,
#    'population': 3485127},
#   '01/30/2022': {'country': 'Uruguay',
#    'date': '01/30/2022',
#    'daily_vaccinations': 3,
#    'total_vaccinations': 7409667,
#    'people_vaccinated': 2893559,
#    'people_fully_vaccinated': 2692022,
#    'total_boosters': 1824086,
#    'population': 3485127},
#   '01/31/2022': {'country': 'Uruguay',
#    'date': '01/31/2022',
#    'daily_vaccinations': 18183,
#    'total_vaccinations': 7427850,
#    'people_vaccinated': 2902331,
#    'people_fully_vaccinated': 2692686,
#    'total_boosters': 1832833,
#    'population': 3485127}},
#  'Uzbekistan': {'01/25/2022': {'country': 'Uzbekistan',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33935149},
#   '01/26/2022': {'country': 'Uzbekistan',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33935149},
#   '01/27/2022': {'country': 'Uzbekistan',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33935149},
#   '01/28/2022': {'country': 'Uzbekistan',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33935149},
#   '01/29/2022': {'country': 'Uzbekistan',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 33935149},
#   '01/30/2022': {'country': 'Uzbekistan',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 40165642,
#    'people_vaccinated': 18071812,
#    'people_fully_vaccinated': 11925969,
#    'total_boosters': None,
#    'population': 33935149},
#   '01/31/2022': {'country': 'Uzbekistan',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 40165642,
#    'people_vaccinated': 18071812,
#    'people_fully_vaccinated': 11925969,
#    'total_boosters': None,
#    'population': 33935149}},
#  'Venezuela': {'01/25/2022': {'country': 'Venezuela',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 28704673},
#   '01/26/2022': {'country': 'Venezuela',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 28704673},
#   '01/27/2022': {'country': 'Venezuela',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 28704673},
#   '01/28/2022': {'country': 'Venezuela',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 35352675,
#    'people_vaccinated': 20836636,
#    'people_fully_vaccinated': 13669072,
#    'total_boosters': 202077,
#    'population': 28704673},
#   '01/29/2022': {'country': 'Venezuela',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 35352675,
#    'people_vaccinated': 20836636,
#    'people_fully_vaccinated': 13669072,
#    'total_boosters': 202077,
#    'population': 28704673},
#   '01/30/2022': {'country': 'Venezuela',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 35352675,
#    'people_vaccinated': 20836636,
#    'people_fully_vaccinated': 13669072,
#    'total_boosters': 202077,
#    'population': 28704673},
#   '01/31/2022': {'country': 'Venezuela',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 35352675,
#    'people_vaccinated': 20836636,
#    'people_fully_vaccinated': 13669072,
#    'total_boosters': 202077,
#    'population': 28704673}},
#  'Vietnam': {'01/25/2022': {'country': 'Vietnam',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610},
#   '01/26/2022': {'country': 'Vietnam',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 179593670,
#    'people_vaccinated': 78987718,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610},
#   '01/27/2022': {'country': 'Vietnam',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 179593670,
#    'people_vaccinated': 78987718,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610},
#   '01/28/2022': {'country': 'Vietnam',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 180876701,
#    'people_vaccinated': 79041734,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610},
#   '01/29/2022': {'country': 'Vietnam',
#    'date': '01/29/2022',
#    'daily_vaccinations': 241714,
#    'total_vaccinations': 181118415,
#    'people_vaccinated': 79055543,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610},
#   '01/30/2022': {'country': 'Vietnam',
#    'date': '01/30/2022',
#    'daily_vaccinations': 161586,
#    'total_vaccinations': 181280001,
#    'people_vaccinated': 79059864,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610},
#   '01/31/2022': {'country': 'Vietnam',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 181280001,
#    'people_vaccinated': 79059864,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 98169610}},
#  'Wales': {'01/25/2022': {'country': 'Wales',
#    'date': '01/25/2022',
#    'daily_vaccinations': 4061,
#    'total_vaccinations': 6739748,
#    'people_vaccinated': 2506955,
#    'people_fully_vaccinated': 2360321,
#    'total_boosters': 1872472,
#    'population': 3169965},
#   '01/26/2022': {'country': 'Wales',
#    'date': '01/26/2022',
#    'daily_vaccinations': 4186,
#    'total_vaccinations': 6743934,
#    'people_vaccinated': 2507419,
#    'people_fully_vaccinated': 2361042,
#    'total_boosters': 1875473,
#    'population': 3169965},
#   '01/27/2022': {'country': 'Wales',
#    'date': '01/27/2022',
#    'daily_vaccinations': 4260,
#    'total_vaccinations': 6748194,
#    'people_vaccinated': 2507907,
#    'people_fully_vaccinated': 2361757,
#    'total_boosters': 1878530,
#    'population': 3169965},
#   '01/28/2022': {'country': 'Wales',
#    'date': '01/28/2022',
#    'daily_vaccinations': 5849,
#    'total_vaccinations': 6754043,
#    'people_vaccinated': 2508486,
#    'people_fully_vaccinated': 2362728,
#    'total_boosters': 1882829,
#    'population': 3169965},
#   '01/29/2022': {'country': 'Wales',
#    'date': '01/29/2022',
#    'daily_vaccinations': 5852,
#    'total_vaccinations': 6759895,
#    'people_vaccinated': 2509780,
#    'people_fully_vaccinated': 2365580,
#    'total_boosters': 1884535,
#    'population': 3169965},
#   '01/30/2022': {'country': 'Wales',
#    'date': '01/30/2022',
#    'daily_vaccinations': 4377,
#    'total_vaccinations': 6764272,
#    'people_vaccinated': 2510515,
#    'people_fully_vaccinated': 2367526,
#    'total_boosters': 1886231,
#    'population': 3169965},
#   '01/31/2022': {'country': 'Wales',
#    'date': '01/31/2022',
#    'daily_vaccinations': 3920,
#    'total_vaccinations': 6768192,
#    'people_vaccinated': 2510933,
#    'people_fully_vaccinated': 2368368,
#    'total_boosters': 1888891,
#    'population': 3169965}},
#  'Yemen': {'01/25/2022': {'country': 'Yemen',
#    'date': '01/25/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': None,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': None,
#    'total_boosters': None,
#    'population': 30494263},
#   '01/26/2022': {'country': 'Yemen',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 732786,
#    'people_vaccinated': 580587,
#    'people_fully_vaccinated': 334079,
#    'total_boosters': None,
#    'population': 30494263},
#   '01/27/2022': {'country': 'Yemen',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 732786,
#    'people_vaccinated': 580587,
#    'people_fully_vaccinated': 334079,
#    'total_boosters': None,
#    'population': 30494263},
#   '01/28/2022': {'country': 'Yemen',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 732786,
#    'people_vaccinated': 580587,
#    'people_fully_vaccinated': 334079,
#    'total_boosters': None,
#    'population': 30494263},
#   '01/29/2022': {'country': 'Yemen',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 732786,
#    'people_vaccinated': 580587,
#    'people_fully_vaccinated': 334079,
#    'total_boosters': None,
#    'population': 30494263},
#   '01/30/2022': {'country': 'Yemen',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 732786,
#    'people_vaccinated': 580587,
#    'people_fully_vaccinated': 334079,
#    'total_boosters': None,
#    'population': 30494263},
#   '01/31/2022': {'country': 'Yemen',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 744060,
#    'people_vaccinated': 588626,
#    'people_fully_vaccinated': 344582,
#    'total_boosters': None,
#    'population': 30494263}},
#  'Zambia': {'01/25/2022': {'country': 'Zambia',
#    'date': '01/25/2022',
#    'daily_vaccinations': 14333,
#    'total_vaccinations': 2305684,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1612504,
#    'total_boosters': None,
#    'population': 18923966},
#   '01/26/2022': {'country': 'Zambia',
#    'date': '01/26/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2305684,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1612504,
#    'total_boosters': None,
#    'population': 18923966},
#   '01/27/2022': {'country': 'Zambia',
#    'date': '01/27/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2337128,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1631552,
#    'total_boosters': None,
#    'population': 18923966},
#   '01/28/2022': {'country': 'Zambia',
#    'date': '01/28/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2337128,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1631552,
#    'total_boosters': None,
#    'population': 18923966},
#   '01/29/2022': {'country': 'Zambia',
#    'date': '01/29/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2370615,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1651733,
#    'total_boosters': None,
#    'population': 18923966},
#   '01/30/2022': {'country': 'Zambia',
#    'date': '01/30/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2370615,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1651733,
#    'total_boosters': None,
#    'population': 18923966},
#   '01/31/2022': {'country': 'Zambia',
#    'date': '01/31/2022',
#    'daily_vaccinations': None,
#    'total_vaccinations': 2386312,
#    'people_vaccinated': None,
#    'people_fully_vaccinated': 1660654,
#    'total_boosters': None,
#    'population': 18923966}},
#  'Zimbabwe': {'01/25/2022': {'country': 'Zimbabwe',
#    'date': '01/25/2022',
#    'daily_vaccinations': 10404,
#    'total_vaccinations': 7577954,
#    'people_vaccinated': 4248576,
#    'people_fully_vaccinated': 3276998,
#    'total_boosters': 52380,
#    'population': 15092969},
#   '01/26/2022': {'country': 'Zimbabwe',
#    'date': '01/26/2022',
#    'daily_vaccinations': 10104,
#    'total_vaccinations': 7588058,
#    'people_vaccinated': 4252654,
#    'people_fully_vaccinated': 3281016,
#    'total_boosters': 54388,
#    'population': 15092969},
#   '01/27/2022': {'country': 'Zimbabwe',
#    'date': '01/27/2022',
#    'daily_vaccinations': 9455,
#    'total_vaccinations': 7597513,
#    'people_vaccinated': 4257075,
#    'people_fully_vaccinated': 3285799,
#    'total_boosters': 54639,
#    'population': 15092969},
#   '01/28/2022': {'country': 'Zimbabwe',
#    'date': '01/28/2022',
#    'daily_vaccinations': 16495,
#    'total_vaccinations': 7614008,
#    'people_vaccinated': 4263356,
#    'people_fully_vaccinated': 3291257,
#    'total_boosters': 59395,
#    'population': 15092969},
#   '01/29/2022': {'country': 'Zimbabwe',
#    'date': '01/29/2022',
#    'daily_vaccinations': 7540,
#    'total_vaccinations': 7621548,
#    'people_vaccinated': 4266023,
#    'people_fully_vaccinated': 3294764,
#    'total_boosters': 60761,
#    'population': 15092969},
#   '01/30/2022': {'country': 'Zimbabwe',
#    'date': '01/30/2022',
#    'daily_vaccinations': 3696,
#    'total_vaccinations': 7625244,
#    'people_vaccinated': 4267826,
#    'people_fully_vaccinated': 3296364,
#    'total_boosters': 61054,
#    'population': 15092969},
#   '01/31/2022': {'country': 'Zimbabwe',
#    'date': '01/31/2022',
#    'daily_vaccinations': 7270,
#    'total_vaccinations': 7632514,
#    'people_vaccinated': 4270759,
#    'people_fully_vaccinated': 3299624,
#    'total_boosters': 62131,
#    'population': 15092969}}}

# %%
#print("Country: ", country, "\tPopulation: ", pop, "\tFully Vaccinated: ", fully)

# %%
#Q6 Another way to do it

sum_vacc_dict ={} #key: country name, value: sum of vaccinations

for date in unique_dates:
    daily_vacc_dict = {}
    daily_vacc_dict = daily_vaccinations_on(date)
    
    for country in daily_vacc_dict:
        if country not in sum_vacc_dict:
            sum_vacc_dict[country] = None

        if daily_vacc_dict[country] != None:
            if sum_vacc_dict[country] == None:
                sum_vacc_dict[country] = 0
        
        sum_vacc_dict[country] = sum_vacc_dict[country] + daily_vacc_dict[country]

sum_vacc_dict

# %%
sum_vacc_dict = {}
sum_vacc = 0

for country in countries:
    
    if country not in sum_vacc_dict:
        sum_vacc_dict[country] = None
        
    for date in dates:
        daily_dict = daily_vaccinations_on(date)
        
        if daily_dict[country] != None:
            sum_vacc += daily_dict[country]
    
    if sum_vacc_dict[country] == None:
        
        if sum_vacc != 0:
            sum_vacc_dict[country] = sum_vacc
        else:
            sum_vacc_dict[country] = None
            
    sum_vacc = 0
    
vaccination_sum = sum_vacc_dict
vaccination_sum
